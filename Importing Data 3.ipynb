# %%
import pandas as pd

# %%
import requests

url = "https://covid-19-coronavirus-statistics.p.rapidapi.com/v1/stats"

headers = {
    'x-rapidapi-host': "covid-19-coronavirus-statistics.p.rapidapi.com",
    'x-rapidapi-key': "d366e464demshb491d67199f58eap1d6a59jsn5b90c78468d4"
    }

response = requests.get("https://covid-19-coronavirus-statistics.p.rapidapi.com/v1/stats", headers=headers)

response
# Out:
# <Response [200]>

# %%
data = response.json()
type(data)

df = pd.DataFrame.from_dict(data)
df["data"][0]
# Out:
# [{'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 13, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 2, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 18, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 2, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 6, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
# ...

# %%
url = "https://coronavirus-monitor.p.rapidapi.com/coronavirus/worldstat.php"

headers = {
    'x-rapidapi-host': "coronavirus-monitor.p.rapidapi.com",
    'x-rapidapi-key': "d366e464demshb491d67199f58eap1d6a59jsn5b90c78468d4"
    }

response2 = requests.get("https://coronavirus-monitor.p.rapidapi.com/coronavirus/worldstat.php", headers=headers)

response2
# Out:
# <Response [200]>

# %%
data = response.json()
type(data)

df1 = pd.DataFrame.from_dict(data)
df1["data"][0]
# Out:
# [{'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 13, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 2, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 18, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 2, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 0, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 6, 'deaths': 0, 'recovered': 0},
#  {'confirmed': 1, 'deaths': 0, 'recovered': 0},
# ...

# %%
url = "https://coronavirus-monitor.p.rapidapi.com/coronavirus/cases_by_particular_country.php"

querystring = {'country': 'USA'}

headers = {
    'x-rapidapi-host': "coronavirus-monitor.p.rapidapi.com",
    'x-rapidapi-key': "d366e464demshb491d67199f58eap1d6a59jsn5b90c78468d4"
    }

response = requests.get(url, headers=headers, params=querystring)

response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'{"country":"USA","stat_by_country":[{"id":"338","country_name":"USA","total_cases":"6,056","new_cases":"1,393","active_cases":"5,881","total_deaths":"101","new_deaths":"15","total_recovered":"74","serious_critical":"12","region":null,"total_cases_per1m":"18.3","record_date":"2020-03-17 21:00:05.485"},{"id":"503","country_name":"USA","total_cases":"6,084","new_cases":"1,421","active_cases":"5,909","total_deaths":"101","new_deaths":"15","total_recovered":"74","serious_critical":"12","region":null,"total_cases_per1m":"18.4","record_date":"2020-03-17 21:10:02.648"},{"id":"668","country_name":"USA","total_cases":"6,137","new_cases":"1,474","active_cases":"5,961","total_deaths":"102","new_deaths":"16","total_recovered":"74","serious_critical":"12","region":null,"total_cases_per1m":"18.5","record_date":"2020-03-17 21:20:01.595"},{"id":"833","country_name":"USA","total_cases":"6,159","new_cases":"1,496","active_cases":"5,983","total_deaths":"102","new_deaths":"16","total_recovered":"74","s
# ...

# %%
data = response.json()
type(data)

df = pd.DataFrame.from_dict(data)
df["stat_by_country"][0]
# Out:
# {'id': '338',
#  'country_name': 'USA',
#  'total_cases': '6,056',
#  'new_cases': '1,393',
#  'active_cases': '5,881',
#  'total_deaths': '101',
#  'new_deaths': '15',
#  'total_recovered': '74',
#  'serious_critical': '12',
#  'region': None,
#  'total_cases_per1m': '18.3',
#  'record_date': '2020-03-17 21:00:05.485'}
