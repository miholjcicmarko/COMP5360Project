# %%
import pandas as pd

# %%
df1 = pd.read_csv("NCVS_PERSONAL_POPULATION_2014-2018.csv")

# %%
df1
# Out:
#          year       weight  gender  race1r  hispanic  ethnic1r  ager  \
# 0        2014  1307.383680       2       1         2         1     7
# 1        2014  2306.155560       1       1         2         1     5
# 2        2014  1977.789830       1       1         2         1     5
# 3        2014  1362.703000       1       2         2         2     4
# 4        2014     0.000000       1       2         2         2     7
# 5        2014     0.000000       2       1         2         1     7
# 6        2014  1346.120820       2       1         2         1     7
# 7        2014  1532.717740       1       1         2         1     7
# 8        2014  2275.052010       1       2         2         2     6
# 9        2014  1488.484815       2       1         2         1     6
# 10       2014  1550.678530       1       1         2         1     6
# 11       2014  1913.124895       2       1         2         1     1
# 12       2014     0.000000       1       2         2         2     6
# ...

# %%
df2 = pd.read_csv("NCVS_PERSONAL_VICTIMIZATION_2014-2018.csv")
df2
# Out:
#       year       weight  gender  race1r  hispanic  ethnic1r  ager  marital2  \
# 0     2014   5865.87421       1       1         2         1     7         4
# 1     2014   5091.44483       2       1         1         4     4         1
# 2     2014   3892.71552       2       3         2         3     5         2
# 3     2014   1952.02221       1       1         1         4     6         1
# 4     2014   1952.02221       1       1         1         4     6         1
# 5     2014   1952.02221       1       1         1         4     6         1
# 6     2014   2217.30396       1       1         2         1     4         1
# 7     2014   1768.12536       2       1         1         4     6         2
# 8     2014   2581.83499       1       1         2         1     1         1
# 9     2014   2737.85790       2       1         2         1     4         1
# 10    2014   2359.26640       1       1         2         1     6         4
# ...

# %%
df3 = pd.read_csv("NCVS_HOUSEHOLD_POPULATION_2014-2018.csv")
df3
# Out:
#         year      weight  msa  hincome  hhage  hhgen  hhhisp  hhrace1r  \
# 0       2014     0.00000    2       99     99      9      99       NaN
# 1       2014  1566.95606    1        5      2      1       2       1.0
# 2       2014  1286.39067    3        3      5      1       2       1.0
# 3       2014  1359.41445    1       88      2      2       2       1.0
# 4       2014  1398.77126    2        5      4      2       1       1.0
# 5       2014  1952.41184    1       88      2      2       2       1.0
# 6       2014     0.00000    1       99     99      9      99       NaN
# 7       2014   920.44631    2        4      5      1       2       1.0
# 8       2014     0.00000    1       99     99      9      99       NaN
# 9       2014  1340.71439    2        7      4      2       2       1.0
# 10      2014  1440.28655    1       88      5      1       2       1.0
# 11      2014  1480.86697    3        2      3      2       2       2.0
# ...

# %%
df4 = pd.read_csv("NCVS_HOUSEHOLD_VICTIMIZATION_2014-2018.csv")
df4
# Out:
#        year      weight  msa  hincome  hhage  hhgen  hhhisp  hhrace1r  \
# 0      2014  2808.64968    2        6      3      1       2         1
# 1      2014  3006.14087    2       88      3      1       2         1
# 2      2014  2812.22564    2       88      5      1       2         1
# 3      2014  2680.82635    1        6      4      2       2         1
# 4      2014  3869.84046    1       88      2      1       2         2
# 5      2014  3104.80446    1        7      2      1       2         3
# 6      2014  2707.85150    2        7      4      2       2         1
# 7      2014  2607.79499    1       88      5      2       2         1
# 8      2014  2775.90891    1        3      3      2       2         2
# 9      2014  2835.57525    2        7      4      2       2         1
# 10     2014  2316.58585    3       88      3      1       2         1
# 11     2014  2698.29790    2        4      2      2       2         1
# ...

# %%
import requests 
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("https://api.usa.gov/crime/fbi/sapi/")

response
# Out:
# <Response [403]>

# %%
response2 = requests.get(" https://www.googleapis.com/civicinfo/v2/elections")

response2
# Out:
# <Response [403]>

# %%
response3 = requests.get("https://www.googleapis.com/civicinfo/v2/divisions")

response3
# Out:
# <Response [403]>
