# %%
from tabula import read_pdf
import pandas as pd
df=read_pdf("./project_files/world_health_index.pdf", pages= '18-21', lattice=True,pandas_options={'header': None})

# %%
import pdfplumber

with pdfplumber.open("./project_files/pdf_resources/world_health_index.pdf") as pdf:
    pages = pdf.pages[17]
    table = pages.extract_table()
    pages2 = pdf.pages[18]
    table2 = pages2.extract_table()
    pages3 = pdf.pages[19]
    table3 = pages3.extract_table()
    pages4 = pdf.pages[20]
    table4 = pages4.extract_table()
    
df = pd.DataFrame(table[1:], columns=table[1])
df.head()
df=df[['Rank','Member State', 'Index']]

data = pd.DataFrame(table2[1:], columns=table2[1])
data=data[['55','Albania', '0.774']]
data=data.rename(columns={'55':'Rank','Albania':'Member State', '0.774':'Index'})                
df=df.append(data,ignore_index=True)

data = pd.DataFrame(table3[1:], columns=table3[1])
data=data[['117','Uzbekistan', '0.599']]
data=data.rename(columns={'117':'Rank','Uzbekistan':'Member State', '0.599':'Index'})                 
df=df.append(data,ignore_index=True)

data = pd.DataFrame(table4[1:], columns=table4[1])
data=data[['178','Chad', '0.303']]
data=data.rename(columns={'178':'Rank','Chad':'Member State', '0.303':'Index'})                  
df=df.append(data,ignore_index=True)

for column in ["Rank", "Member State", 'Index']:
    df[column] = df[column].str.replace(" ", "")
    df[column] = df[column].replace('\n','', regex=True)
df=df.dropna()
df=df.drop([0])
df.set_index('Rank')
df['Rank']=df['Rank'].astype(int)
df['Index']=df['Index'].astype(float)
df['Member State']=df['Member State'].astype(str)
df.dtypes
# Out:
# Rank              int32
# Member State     object
# Index           float64
# dtype: object

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
    
df.to_csv(r'C:\Users\austi\Documents\GitHub\COMP5360Project\project_files\WorldHealthIndex.csv', index=False)
# Out:
#      Rank                          Member State  Index
# 1       1                                France  0.994
# 2       2                                 Italy  0.991
# 3       3                             SanMarino  0.988
# 4       4                               Andorra  0.982
# 5       5                                 Malta  0.978
# 6       6                             Singapore  0.973
# 7       7                                 Spain  0.972
# 8       8                                  Oman  0.961
# 9       9                               Austria  0.959
# 10     10                                 Japan  0.957
# 11     11                                Norway  0.955
# 12     12                              Portugal  0.945
# 13     13                                Monaco  0.943
# 14     14                                Greece  0.933
# 15     15                               Iceland  0.932
# 16     16                            Luxembourg  0.928
# 17     17                           Netherlands  0.928
# 18     18                         UnitedKingdom  0.925
# 19     19                               Ireland  0.924
# 20     20                           Switzerland  0.916
# 21     21                               Belgium  0.915
# 22     22                              Colombia  0.910
# 23     23                                Sweden  0.908
# 24     24                                Cyprus  0.906
# 25     25                               Germany  0.902
# 26     26                           SaudiArabia  0.894
# 27     27                    UnitedArabEmirates  0.886
# 28     28                                Israel  0.884
# 29     29                               Morocco  0.882
# 30     30                                Canada  0.881
# 31     31                               Finland  0.881
# 32     32                             Australia  0.876
# 33     33                                 Chile  0.870
# 34     34                               Denmark  0.862
# 35     35                              Dominica  0.854
# 36     36                             CostaRica  0.849
# 37     37                 UnitedStatesofAmerica  0.838
# 38     38                              Slovenia  0.838
# 39     39                                  Cuba  0.834
# 40     40                      BruneiDarussalam  0.829
# 41     41                            NewZealand  0.827
# 42     42                               Bahrain  0.824
# 43     43                               Croatia  0.812
# 44     44                                 Qatar  0.812
# 45     45                                Kuwait  0.810
# 46     46                              Barbados  0.808
# 47     47                              Thailand  0.807
# 48     48                         CzechRepublic  0.805
# 49     49                              Malaysia  0.802
# 50     50                                Poland  0.793
# 51     51                     DominicanRepublic  0.789
# 52     52                               Tunisia  0.785
# 53     53                               Jamaica  0.782
# 54     54                  Venezuela,Bolivarian  0.775
# 55     55                               Albania  0.774
# 56     56                            Seychelles  0.773
# 57     57                              Paraguay  0.761
# 58     58                       RepublicofKorea  0.759
# 59     59                               Senegal  0.756
# 60     60                           Philippines  0.755
# 61     61                                Mexico  0.755
# 62     62                              Slovakia  0.754
# 63     63                                 Egypt  0.752
# 64     64                            Kazakhstan  0.752
# 65     65                               Uruguay  0.745
# 66     66                               Hungary  0.743
# 67     67                     TrinidadandTobago  0.742
# 68     68                            SaintLucia  0.740
# 69     69                                Belize  0.736
# 70     70                                Turkey  0.734
# 71     71                             Nicaragua  0.733
# 72     72                               Belarus  0.723
# 73     73                             Lithuania  0.722
# 74     74          SaintVincentandtheGrenadines  0.722
# 76     75                             Argentina  0.722
# 77     76                              SriLanka  0.716
# 78     77                               Estonia  0.714
# 79     78                             Guatemala  0.713
# 80     79                               Ukraine  0.708
# 81     80                        SolomonIslands  0.705
# 82     81                               Algeria  0.701
# 83     82                                 Palau  0.700
# 84     83                                Jordan  0.698
# 85     84                             Mauritius  0.691
# 86     85                               Grenada  0.689
# 87     86                     AntiguaandBarbuda  0.688
# 88     87                  LibyanArabJamahiriya  0.683
# 89     88                            Bangladesh  0.675
# 90     89  TheformerYugoslavRepublicofMacedonia  0.664
# 92     90                  BosniaandHerzegovina  0.664
# 93     91                               Lebanon  0.664
# 94     92                             Indonesia  0.660
# 95     93                Iran,IslamicRepublicof  0.659
# 96     94                               Bahamas  0.657
# 97     95                                Panama  0.656
# 98     96                                  Fiji  0.653
# 99     97                                 Benin  0.647
# 100    98                                 Nauru  0.647
# 101    99                               Romania  0.645
# 102   100                    SaintKittsandNevis  0.643
# 103   101                     RepublicofMoldova  0.639
# 104   102                              Bulgaria  0.639
# 105   103                                  Iraq  0.637
# 106   104                               Armenia  0.630
# 107   105                                Latvia  0.630
# 108   106                            Yugoslavia  0.629
# 109   107                           CookIslands  0.628
# 110   108                    SyrianArabRepublic  0.628
# 111   109                            Azerbaijan  0.626
# 112   110                              Suriname  0.623
# 113   111                               Ecuador  0.619
# 114   112                                 India  0.617
# 115   113                             CapeVerde  0.617
# 116   114                               Georgia  0.615
# 117   115                            ElSalvador  0.608
# 118   117                            Uzbekistan  0.599
# 119   118                               Comoros  0.592
# 120   119                                 Samoa  0.589
# 121   120                                 Yemen  0.587
# 122   121                                  Niue  0.584
# 123   122                              Pakistan  0.583
# 124   123          Micronesia,FederatedStatesof  0.579
# 126   124                                Bhutan  0.575
# 127   125                                Brazil  0.573
# 128   126                               Bolivia  0.571
# 129   127                               Vanuatu  0.559
# 130   128                                Guyana  0.554
# 131   129                                  Peru  0.547
# 132   130                     RussianFederation  0.544
# 133   131                              Honduras  0.544
# 134   132                           BurkinaFaso  0.543
# 135   133                    SaoTomeandPrincipe  0.535
# 136   134                                 Sudan  0.524
# 137   135                                 Ghana  0.522
# 138   136                                Tuvalu  0.518
# 139   137                          Côted'Ivoire  0.517
# 140   138                                 Haiti  0.517
# 141   139                                 Gabon  0.511
# 142   140                                 Kenya  0.505
# 143   141                       MarshallIslands  0.504
# 144   142                              Kiribati  0.495
# 145   143                               Burundi  0.494
# 146   144                                 China  0.485
# 147   145                              Mongolia  0.483
# 148   146                                Gambia  0.482
# 149   147                              Maldives  0.477
# 150   148                        PapuaNewGuinea  0.467
# 151   149                                Uganda  0.464
# 152   150                                 Nepal  0.457
# 153   151                            Kyrgyzstan  0.455
# 154   152                                  Togo  0.449
# 155   153                          Turkmenistan  0.443
# 156   154                            Tajikistan  0.428
# 157   155                              Zimbabwe  0.427
# 158   156              UnitedRepublicofTanzania  0.422
# 159   157                              Djibouti  0.414
# 160   158                               Eritrea  0.399
# 161   159                            Madagascar  0.397
# 162   160                               VietNam  0.393
# 163   161                                Guinea  0.385
# 164   162                            Mauritania  0.384
# 165   163                                  Mali  0.361
# 166   164                              Cameroon  0.357
# 167   165         LaoPeople'sDemocraticRepublic  0.356
# 169   166                                 Congo  0.354
# 170   167     DemocraticPeople'sRepublicofKorea  0.353
# 172   168                               Namibia  0.340
# 173   169                              Botswana  0.338
# 174   170                                 Niger  0.337
# 175   171                      EquatorialGuinea  0.337
# 176   172                                Rwanda  0.327
# 177   173                           Afghanistan  0.325
# 178   174                              Cambodia  0.322
# 179   175                           SouthAfrica  0.319
# 180   176                         Guinea-Bissau  0.314
# 181   178                                  Chad  0.303
# 182   179                               Somalia  0.286
# 183   180                              Ethiopia  0.276
# 184   181                                Angola  0.275
# 185   182                                Zambia  0.269
# 186   183                               Lesotho  0.266
# 187   184                            Mozambique  0.260
# 188   185                                Malawi  0.251
# 189   186                               Liberia  0.200
# 190   187                               Nigeria  0.176
# 191   188          DemocraticRepublicoftheCongo  0.171
# 193   189                CentralAfricanRepublic  0.156
# 194   190                               Myanmar  0.138
# 195   191                           SierraLeone  0.000
