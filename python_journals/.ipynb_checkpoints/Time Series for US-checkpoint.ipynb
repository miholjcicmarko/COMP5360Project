# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\austi\Documents\GitHub\COMP5360Project\project_files\csv_files\CLEANCDRData.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0bf122a140d7> in <module>
# ----> 1 data = pd.read_csv(r"C:\Users\austi\Documents\GitHub\COMP5360Project\project_files\csv_files\CLEANCDRData.csv")
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# //anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:\\Users\\austi\\Documents\\GitHub\\COMP5360Project\\project_files\\csv_files\\CLEANCDRData.csv' does not exist: b'C:\\Users\\austi\\Documents\\GitHub\\COMP5360Project\\project_files\\csv_files\\CLEANCDRData.csv'

# %%
data = pd.read_csv(r"/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/CLEANCDRData.csv")
data
# Out:
#        Country/Region Last Update  Confirmed  Deaths  Recovered
# 0               China     1/22/20          1       0          0
# 1               China     1/22/20         14       0          0
# 2               China     1/22/20          6       0          0
# 3               China     1/22/20          1       0          0
# 4               China     1/22/20          0       0          0
# 5               China     1/22/20         26       0          0
# 6               China     1/22/20          2       0          0
# 7               China     1/22/20          1       0          0
# 8               China     1/22/20          4       0          0
# 9               China     1/22/20          1       0          0
# 10              China     1/22/20          0       0          0
# 11              China     1/22/20          5       0          0
# 12              China     1/22/20        444      17         28
# 13              China     1/22/20          4       0          0
# 14              China     1/22/20          0       0          0
# 15              China     1/22/20          1       0          0
# 16              China     1/22/20          2       0          0
# 17              China     1/22/20          0       0          0
# 18              China     1/22/20          2       0          0
# 19              China     1/22/20          1       0          0
# 20              China     1/22/20          0       0          0
# 21              China     1/22/20          0       0          0
# 22              China     1/22/20          2       0          0
# 23              China     1/22/20          9       0          0
# 24              China     1/22/20          1       0          0
# 25              China     1/22/20          5       0          0
# 26              China     1/22/20          4       0          0
# 27              China     1/22/20          0       0          0
# 28                 US     1/22/20          1       0          0
# 29              China     1/22/20          0       0          0
# ...               ...         ...        ...     ...        ...
# 28369  United Kingdom     3/29/20         42       0          0
# 28370           China     3/29/20        644       0        631
# 28371           China     3/29/20        937       1        934
# 28372           China     3/29/20         98       1         92
# 28373           China     3/29/20        134       2        124
# 28374  United Kingdom     3/29/20          5       0          0
# 28375       Australia     3/29/20       1791       8          4
# 28376              US     3/29/20          0       0          0
# 28377       Australia     3/29/20         15       0          0
# 28378              US     3/29/20        127       3          0
# 28379       Australia     3/29/20        656       2          8
# 28380              US     3/29/20          0       0       2665
# 28381           China     3/29/20        492       5        334
# 28382           China     3/29/20        136       0        133
# 28383           China     3/29/20        550       3        536
# 28384       Australia     3/29/20        299       0          6
# 28385       Australia     3/29/20         66       0          5
# 28386           China     3/29/20        166       3        133
# 28387  United Kingdom     3/29/20          4       0          0
# 28388       Australia     3/29/20        769       4        191
# 28389              US     3/29/20          0       0          0
# 28390       Australia     3/29/20        311       2         28
# 28391           China     3/29/20       1254       1       1225
# 28392           India     3/29/20       1024      27         95
# 28393            Iran     3/29/20      38309    2640      12391
# 28394           Italy     3/29/20      97689   10779      13030
# 28395     South Korea     3/29/20       9583     152       5033
# 28396     New Zealand     3/29/20        514       1         56
# 28397            Peru     3/29/20        852      18         16
# 28398  United Kingdom     3/29/20      19522    1228        135
#
# [28399 rows x 5 columns]

# %%
from datetime import datetime
dataC = data[data["Country/Region"] == "China"]  
groupDate = dataC.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataChina = data[data["Country/Region"] == "China"]  
dataChina
groupChina = dataChina.groupby("Last Update")
dChina = groupChina.sum()
dChina = list(dChina["Confirmed"].values)
dChina.sort()

dfChina = pd.DataFrame({"China": dChina})
dfChina = pd.concat([dfDate,dfChina], axis=1, sort = False)
dfChina = dfChina.rename(columns={0: "Date"})
dfChina = dfChina.set_index('Date')
dfChina
# Out:
#          China
# Date
# 1/22/20    547
# 1/23/20    639
# 1/24/20    916
# 1/25/20   1399
# 1/26/20   2062
# 1/27/20   2863
# 1/28/20   5494
# 1/29/20   6070
# 1/30/20   8124
# 1/31/20   9783
# 2/1/20   11842
# 2/02/20  16606
# 2/03/20  19692
# 2/04/20  23679
# 2/05/20  27374
# 2/06/20  30490
# 2/07/20  34056
# 2/08/20  36759
# 2/09/20  39771
# 2/10/20  42168
# 2/11/20  44268
# 2/12/20  44699
# 2/13/20  59831
# 2/14/20  66183
# 2/15/20  68346
# 2/16/20  70357
# 2/17/20  71988
# 2/18/20  72345
# 2/19/20  73594
# 2/20/20  73602
# ...        ...
# 2/29/20  74606
# 3/1/20   74863
# 3/2/20   74980
# 3/3/20   75133
# 3/4/20   75471
# 3/5/20   76112
# 3/6/20   76516
# 3/7/20   76600
# 3/8/20   76741
# 3/9/20   76769
# 3/10/20  76902
# 3/11/20  76919
# 3/12/20  76987
# 3/13/20  77201
# 3/14/20  77331
# 3/15/20  77474
# 3/16/20  77817
# 3/17/20  77900
# 3/18/20  78330
# 3/19/20  78388
# 3/20/20  78619
# 3/21/20  78995
# 3/22/20  79455
# 3/23/20  79465
# 3/24/20  79538
# 3/25/20  79574
# 3/26/20  79588
# 3/27/20  79749
# 3/28/20  79771
# 3/29/20  80921
#
# [68 rows x 1 columns]

# %%
dataUS = data[data["Country/Region"] == "US"]  
groupDate = dataUS.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataUS = data[data["Country/Region"] == "US"]  
dataUS
groupUS = dataUS.groupby("Last Update")
dUS = groupUS.sum()
dUS = list(dUS["Confirmed"].values)

dUS.sort()

dfUS = pd.DataFrame({"US": dUS})
dfUS = pd.concat([dfDate,dfUS], axis=1, sort = False)
dfUS = dfUS.rename(columns={0: "Date"})
dfUS = dfUS.set_index('Date')

# %%
dataIt = data[data["Country/Region"] == "Italy"]  
groupDate = dataIt.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataIt = data[data["Country/Region"] == "Italy"]  
group = dataIt.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Italy": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfIt = df.set_index('Date')

# %%
dataNZ = data[data["Country/Region"] == "New Zealand"]  
groupDate = dataNZ.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataNZ = data[data["Country/Region"] == "New Zealand"]  
group = dataNZ.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"New Zealand": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfNZ = df.set_index('Date')

# %%
dataSK = data[data["Country/Region"] == "South Korea"]  
groupDate = dataSK.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataSK = data[data["Country/Region"] == "South Korea"]  
group = dataSK.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"South Korea": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfSK = df.set_index('Date')

# %%
dataUK = data[data["Country/Region"] == "United Kingdom"]  
groupDate = dataUK.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataUK = data[data["Country/Region"] == "United Kingdom"]  
group = dataUK.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)

d.sort()

df = pd.DataFrame({"United Kingdom": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfUK = df.set_index('Date')
pd.set_option("max_rows", None)

# %%
dataI = data[data["Country/Region"] == "Iran"]  
groupDate = dataI.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataI = data[data["Country/Region"] == "Iran"]  
group = dataI.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Iran": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfI = df.set_index('Date')

# %%
dataAuS = data[data["Country/Region"] == "Australia"]  
groupDate = dataAuS.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataAuS = data[data["Country/Region"] == "Australia"]  
group = dataAuS.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Australia": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfAuS = df.set_index('Date')

# %%
dataIND = data[data["Country/Region"] == "India"]  
groupDate = dataIND.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataIND = data[data["Country/Region"] == "India"]  
group = dataIND.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"India": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfIND = df.set_index('Date')

# %%
dataP = data[data["Country/Region"] == "Peru"]  
print(dataP)
groupDate = dataP.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)
# Out:
#       Country/Region Last Update  Confirmed  Deaths  Recovered
# 1587            Peru      3/6/20          1       0          0
# 1715            Peru      3/8/20          6       0          0
# 1784            Peru      3/9/20          7       0          0
# 1852            Peru     3/10/20         11       0          0
# 2019            Peru     3/12/20         15       0          0
# 2094            Peru     3/14/20         38       0          0
# 2165            Peru     3/15/20         43       0          0
# 2225            Peru     3/16/20         86       0          0
# 2305            Peru     3/17/20        117       0          1
# 2379            Peru     3/18/20        145       0          1
# 2449            Peru     3/19/20        234       0          1
# 2538            Peru     3/20/20        234       3          1
# 2619            Peru     3/21/20        318       5          1
# 5880            Peru     3/22/20        363       5          1
# 9104            Peru     3/23/20        395       5          1
# 12318           Peru     3/24/20        416       7          1
# 15530           Peru     3/25/20        480       9          1
# 18741           Peru     3/26/20        580       9         14
# 21957           Peru     3/27/20        635      11         16
# 25173           Peru     3/28/20        671      16         16
# 28397           Peru     3/29/20        852      18         16

# %%
dataP = data[data["Country/Region"] == "Peru"]  
print(dataP)
group = dataP.groupby("Last Update")
print(group)
d = group.sum()
print(d)
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Peru": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfP = df.set_index('Date')
# Out:
#       Country/Region Last Update  Confirmed  Deaths  Recovered
# 1587            Peru      3/6/20          1       0          0
# 1715            Peru      3/8/20          6       0          0
# 1784            Peru      3/9/20          7       0          0
# 1852            Peru     3/10/20         11       0          0
# 2019            Peru     3/12/20         15       0          0
# 2094            Peru     3/14/20         38       0          0
# 2165            Peru     3/15/20         43       0          0
# 2225            Peru     3/16/20         86       0          0
# 2305            Peru     3/17/20        117       0          1
# 2379            Peru     3/18/20        145       0          1
# 2449            Peru     3/19/20        234       0          1
# 2538            Peru     3/20/20        234       3          1
# 2619            Peru     3/21/20        318       5          1
# 5880            Peru     3/22/20        363       5          1
# 9104            Peru     3/23/20        395       5          1
# 12318           Peru     3/24/20        416       7          1
# 15530           Peru     3/25/20        480       9          1
# 18741           Peru     3/26/20        580       9         14
# 21957           Peru     3/27/20        635      11         16
# 25173           Peru     3/28/20        671      16         16
# 28397           Peru     3/29/20        852      18         16
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x11da84910>
#              Confirmed  Deaths  Recovered
# Last Update
# 3/10/20             11       0          0
# 3/12/20             15       0          0
# 3/14/20             38       0          0
# 3/15/20             43       0          0
# 3/16/20             86       0          0
# 3/17/20            117       0          1
# 3/18/20            145       0          1
# 3/19/20            234       0          1
# 3/20/20            234       3          1
# 3/21/20            318       5          1
# 3/22/20            363       5          1
# 3/23/20            395       5          1
# 3/24/20            416       7          1
# 3/25/20            480       9          1
# 3/26/20            580       9         14
# 3/27/20            635      11         16
# 3/28/20            671      16         16
# 3/29/20            852      18         16
# 3/6/20               1       0          0
# 3/8/20               6       0          0
# 3/9/20               7       0          0

# %%
#Countries=['US','Italy', 'China','United Kingdom','Iran',  'South Korea','Australia','India','New Zealand', 'Peru']
#
#dataP = data[data["Country/Region"] == "Peru"]  
#print(dataP)
#groupDate = dataP.groupby("Last Update")
#df1 = groupDate.count()
#
#df1 = list(df1.index.values)
#df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))
#
#dfDate = pd.DataFrame(df1)
#
#dataP = data[data["Country/Region"] == "Peru"]  
#print(dataP)
#group = dataP.groupby("Last Update")
#print(group)
#d = group.sum()
#print(d)
#d = list(d["Confirmed"].values)
#d.sort()

#df = pd.DataFrame({"Peru": d})
#df = pd.concat([dfDate,df], axis=1, sort = False)
#df = df.rename(columns={0: "Date"})
#dfP = df.set_index('Date')
#
#for country in Countries:
#    print(country)
#    data[country]=data[data['Country/Region']==country]
#    print(data[country])
#    groupdate=data[country].groupby('Last Update')
#    df=groupdate.count()
#    df=list(df.index.values)
#    df.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))
#

# %%
dfdata = pd.concat([dfChina,dfUS, dfIt, dfSK, dfUK, dfI,dfAuS], axis=1, sort = False)
dfdata[['US','Italy','South Korea','United Kingdom', 'Iran','Australia']]= dfdata[['US','Italy','South Korea','United Kingdom', 'Iran','Australia']].interpolate()
dfdata=dfdata.fillna(0)
dfdata
# Out:
#          China         US         Italy  South Korea  United Kingdom     Iran  \
# 1/22/20    547       1.00      0.000000          1.0        0.000000      0.0
# 1/23/20    639       1.00      0.000000          1.0        0.000000      0.0
# 1/24/20    916       1.00      0.000000          2.0        0.000000      0.0
# 1/25/20   1399       1.00      0.000000          2.0        0.000000      0.0
# 1/26/20   2062       2.00      0.000000          3.0        0.000000      0.0
# 1/27/20   2863       2.00      0.000000          4.0        0.000000      0.0
# 1/28/20   5494       2.00      0.000000          4.0        0.000000      0.0
# 1/29/20   6070       3.00      0.000000          4.0        0.000000      0.0
# 1/30/20   8124       3.00      0.000000          4.0        0.000000      0.0
# 1/31/20   9783       4.00      2.000000         11.0        2.000000      0.0
# 2/1/20   11842       5.00      2.142857         12.0        2.000000      0.0
# 2/02/20  16606       5.00      2.285714         15.0        2.166667      0.0
# 2/03/20  19692       5.00      2.428571         15.5        2.333333      0.0
# 2/04/20  23679       5.00      2.571429         16.0        2.500000      0.0
# 2/05/20  27374       5.00      2.714286         19.0        2.666667      0.0
# 2/06/20  30490       5.00      2.857143         23.0        2.833333      0.0
# 2/07/20  34056       5.00      3.000000         24.0        3.000000      0.0
# 2/08/20  36759       5.00      4.214286         24.5        3.000000      0.0
# 2/09/20  39771       5.00      5.428571         25.0        3.000000      0.0
# 2/10/20  42168       5.00      6.642857         27.0        3.000000      0.0
# 2/11/20  44268       5.00      7.857143         28.0        5.500000      0.0
# 2/12/20  44699       5.50      9.071429         28.0        8.000000      0.0
# 2/13/20  59831       6.00     10.285714         28.0        8.250000      0.0
# 2/14/20  66183       6.25     11.500000         28.0        8.500000      0.0
# 2/15/20  68346       6.50     12.714286         28.0        8.750000      0.0
# 2/16/20  70357       6.75     13.928571         29.0        9.000000      0.0
# 2/17/20  71988       7.00     15.142857         30.0        9.000000      0.0
# 2/18/20  72345       7.25     16.357143         31.0        9.000000      0.0
# 2/19/20  73594       7.50     17.571429         67.5        9.000000      2.0
# 2/20/20  73602       7.75     18.785714        104.0        9.000000      5.0
# 2/21/20  73609       8.00     20.000000        204.0        9.000000     18.0
# 2/22/20  73937      11.00     62.000000        433.0        9.000000     28.0
# 2/23/20  73960      13.00    155.000000        602.0        9.000000     43.0
# 2/24/20  74138      15.00    229.000000        833.0        9.000000     61.0
# 2/25/20  74394      18.00    322.000000        977.0       10.333333     95.0
# 2/26/20  74407      24.00    453.000000       1261.0       11.666667    139.0
# 2/27/20  74533      36.00    655.000000       1766.0       13.000000    245.0
# 2/28/20  74545      37.00    888.000000       2337.0       15.000000    388.0
# 2/29/20  74606      42.00   1128.000000       3150.0       20.000000    593.0
# 3/1/20   74863      45.00   1694.000000       3736.0       23.000000    978.0
# 3/2/20   74980      54.00   2036.000000       4335.0       36.000000   1501.0
# 3/3/20   75133      62.00   2502.000000       5186.0       40.000000   2336.0
# 3/4/20   75471      88.00   3089.000000       5621.0       51.000000   2922.0
# 3/5/20   76112     142.00   3858.000000       6088.0       85.000000   3513.0
# 3/6/20   76516     168.00   4636.000000       6593.0      115.000000   4747.0
# 3/7/20   76600     203.00   5883.000000       7041.0      163.000000   5823.0
# 3/8/20   76741     311.00   7375.000000       7314.0      206.000000   6566.0
# 3/9/20   76769     387.00   9172.000000       7478.0      273.000000   7161.0
# 3/10/20  76902     959.00  10149.000000       7616.5      321.000000   8080.5
# 3/11/20  76919    1200.00  12462.000000       7755.0      382.000000   9000.0
# 3/12/20  76987    1554.00  15360.333333       7869.0      407.666667  10075.0
# 3/13/20  77201    2085.50  18258.666667       7977.5      433.333333  11402.0
# 3/14/20  77331    2617.00  21157.000000       8086.0      459.000000  12729.0
# 3/15/20  77474    2877.00  24568.500000       8162.0     1141.000000  13938.0
# 3/16/20  77817    4612.00  27980.000000       8236.0     1550.000000  14991.0
# 3/17/20  77900    6287.00  31506.000000       8320.0     1953.000000  16169.0
# 3/18/20  78330    7447.00  35713.000000       8413.0     2635.000000  17361.0
# 3/19/20  78388   13604.00  41035.000000       8565.0     2715.000000  18407.0
# 3/20/20  78619   19057.00  47021.000000       8652.0     3998.000000  19644.0
# 3/21/20  78995   25335.00  53578.000000       8799.0     5052.000000  20610.0
# 3/22/20  79455   33746.00  59138.000000       8897.0     5741.000000  21638.0
# 3/23/20  79465   43667.00  63927.000000       8961.0     6726.000000  23049.0
# 3/24/20  79538   53740.00  69176.000000       9037.0     8164.000000  24811.0
# 3/25/20  79574   65778.00  74386.000000       9137.0     9640.000000  27017.0
# 3/26/20  79588   83836.00  80589.000000       9241.0    11812.000000  29406.0
# 3/27/20  79749  101657.00  86498.000000       9332.0    14745.000000  32332.0
# 3/28/20  79771  121478.00  92472.000000       9478.0    17312.000000  35408.0
# 3/29/20  80921  140886.00  97689.000000       9583.0    19780.000000  38309.0
#
#          Australia
# 1/22/20       0.00
# 1/23/20       0.00
# 1/24/20       1.00
# 1/25/20       2.00
# 1/26/20       3.00
# 1/27/20       4.00
# 1/28/20       4.00
# 1/29/20       4.00
# 1/30/20       5.00
# 1/31/20       5.00
# 2/1/20        5.00
# 2/02/20       5.00
# 2/03/20       5.00
# 2/04/20       5.00
# 2/05/20       6.00
# 2/06/20       7.00
# 2/07/20       8.00
# 2/08/20       8.00
# 2/09/20       8.00
# 2/10/20       8.00
# 2/11/20       8.00
# 2/12/20       8.00
# 2/13/20       8.00
# 2/14/20       8.00
# 2/15/20       8.00
# 2/16/20       8.00
# 2/17/20       8.00
# 2/18/20       8.25
# 2/19/20       8.50
# 2/20/20       8.75
# 2/21/20       9.00
# 2/22/20       9.00
# 2/23/20       9.00
# 2/24/20       9.00
# 2/25/20       9.00
# 2/26/20       9.00
# 2/27/20       9.00
# 2/28/20       9.50
# 2/29/20      10.00
# 3/1/20       12.00
# 3/2/20       21.00
# 3/3/20       24.00
# 3/4/20       26.00
# 3/5/20       33.00
# 3/6/20       38.00
# 3/7/20       39.00
# 3/8/20       55.00
# 3/9/20       67.00
# 3/10/20      98.00
# 3/11/20     127.00
# 3/12/20     168.00
# 3/13/20     209.00
# 3/14/20     250.00
# 3/15/20     278.00
# 3/16/20     376.00
# 3/17/20     413.00
# 3/18/20     559.00
# 3/19/20     567.00
# 3/20/20     660.00
# 3/21/20    1068.00
# 3/22/20    1490.00
# 3/23/20    1682.00
# 3/24/20    2044.00
# 3/25/20    2364.00
# 3/26/20    2810.00
# 3/27/20    3143.00
# 3/28/20    3640.00
# 3/29/20    3984.00

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (25, 15)

fig, axs = plt.subplots(5, 2)
axs[0, 0].plot(dfChina);
axs[0, 0].set_title('China')
axs[0, 1].plot(dfUS)
axs[0, 1].set_title('US')
axs[1, 0].plot(dfIt)
axs[1, 0].set_title('Italy')
axs[1, 1].plot(dfNZ)
axs[1, 1].set_title('New Zealand')
axs[2, 0].plot(dfSK)
axs[2, 0].set_title('South Korea')
axs[2, 1].plot(dfUK)
axs[2, 1].set_title('United Kingdom')
axs[3, 0].plot(dfI)
axs[3, 0].set_title('Iran')
axs[3, 1].plot(dfAuS)
axs[3, 1].set_title('Australia')
axs[4, 0].plot(dfIND)
axs[4, 0].set_title('India')
axs[4, 1].plot(dfP)
axs[4, 1].set_title('Peru')

for ax in axs.flat:
    ax.set(xlabel='Date', ylabel='Total Confirmed Cases')
    ax.tick_params(labelrotation=90, axis = 'x')
       
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
#
#dfChina.plot(grid = True);
#dfUS.plot(grid = True);
#dfIt.plot(grid = True);
#dfNZ.plot(grid = True);
#dfSK.plot(grid = True);
#dfUK.plot(grid = True);
#dfI.plot(grid = True);
#dfAuS.plot(grid = True);
#dfIND.plot(grid=True);
#dfP.plot(grid = True);

# %%
dfdata.plot(grid = True);
plt.legend(loc=2, prop={'size': 15})
