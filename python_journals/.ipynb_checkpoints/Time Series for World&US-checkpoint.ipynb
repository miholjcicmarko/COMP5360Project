# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/CLEANCDRData.csv")

# %%
from datetime import datetime
groupDate = data.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataChina = data[data["Country/Region"] == "China"]  
dataChina
groupChina = dataChina.groupby("Last Update")
dChina = groupChina.sum()
dChina = list(dChina["Confirmed"].values)
dChina.sort()

dfChina = pd.DataFrame({"China": dChina})
dfChina = pd.concat([dfDate,dfChina], axis=1, sort = False)
dfChina = dfChina.rename(columns={0: "Date"})
dfChina = dfChina.set_index('Date')

# %%
dataUS = data[data["Country/Region"] == "US"]  
groupDate = dataUS.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataUS = data[data["Country/Region"] == "US"]  
dataUS
groupUS = dataUS.groupby("Last Update")
dUS = groupUS.sum()
dUS = list(dUS["Confirmed"].values)
dUS.sort()

dfUS = pd.DataFrame({"US": dUS})
dfUS = pd.concat([dfDate,dfUS], axis=1, sort = False)
dfUS = dfUS.rename(columns={0: "Date"})
dfUS = dfUS.set_index('Date')

# %%
dataIt = data[data["Country/Region"] == "Italy"]  
groupDate = dataIt.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataIt = data[data["Country/Region"] == "Italy"]  
group = dataIt.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Italy": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfIt = df.set_index('Date')

# %%
dataNZ = data[data["Country/Region"] == "New Zealand"]  
groupDate = dataNZ.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataNZ = data[data["Country/Region"] == "New Zealand"]  
group = dataNZ.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"New Zealand": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfNZ = df.set_index('Date')

# %%
dataSK = data[data["Country/Region"] == "South Korea"]  
groupDate = dataSK.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataSK = data[data["Country/Region"] == "South Korea"]  
group = dataSK.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"South Korea": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfSK = df.set_index('Date')

# %%
dataUK = data[data["Country/Region"] == "United Kingdom"]  
groupDate = dataUK.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataUK = data[data["Country/Region"] == "United Kingdom"]  
group = dataUK.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"United Kingdom": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfUK = df.set_index('Date')

# %%
dataI = data[data["Country/Region"] == "Iran"]  
groupDate = dataI.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataI = data[data["Country/Region"] == "Iran"]  
group = dataI.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Iran": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfI = df.set_index('Date')

# %%
dataS = data[data["Country/Region"] == "Singapore"]  
groupDate = dataS.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataS = data[data["Country/Region"] == "Singapore"]  
group = dataS.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Singapore": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfS = df.set_index('Date')

# %%
dataIND = data[data["Country/Region"] == "India"]  
groupDate = dataIND.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataIND = data[data["Country/Region"] == "India"]  
group = dataIND.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"India": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfIND = df.set_index('Date')

# %%
dataP = data[data["Country/Region"] == "Peru"]  
groupDate = dataP.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)

# %%
dataP = data[data["Country/Region"] == "Peru"]  
group = dataP.groupby("Last Update")
d = group.sum()
d = list(d["Confirmed"].values)
d.sort()

df = pd.DataFrame({"Peru": d})
df = pd.concat([dfDate,df], axis=1, sort = False)
df = df.rename(columns={0: "Date"})
dfP = df.set_index('Date')

# %%
dfdata = pd.concat([dfChina,dfUS, dfIt, dfSK, dfUK, dfI], axis=1, sort = False)
dfdata
# Out:
#          China        US    Italy  South Korea  United Kingdom     Iran
# 1/22/20    547       1.0      NaN          1.0             NaN      NaN
# 1/23/20    639       1.0      NaN          1.0             NaN      NaN
# 1/24/20    916       1.0      NaN          2.0             NaN      NaN
# 1/25/20   1399       1.0      NaN          2.0             NaN      NaN
# 1/26/20   2062       2.0      NaN          3.0             NaN      NaN
# 1/27/20   2863       2.0      NaN          4.0             NaN      NaN
# 1/28/20   5494       2.0      NaN          4.0             NaN      NaN
# 1/29/20   6070       3.0      NaN          4.0             NaN      NaN
# 1/30/20   8124       3.0      NaN          4.0             NaN      NaN
# 1/31/20   9783       4.0      2.0         11.0             NaN      NaN
# 2/1/20   11842       5.0      NaN         12.0             NaN      NaN
# 2/2/20   16606       NaN      NaN         15.0             NaN      NaN
# 2/3/20   19692       5.0      NaN          NaN             NaN      NaN
# 2/4/20   23679       NaN      NaN         16.0             NaN      NaN
# 2/5/20   27374       5.0      NaN         19.0             NaN      NaN
# 2/6/20   30490       NaN      NaN         23.0             NaN      NaN
# 2/7/20   34056       NaN      3.0         24.0             NaN      NaN
# 2/8/20   36759       NaN      NaN          NaN             NaN      NaN
# 2/9/20   39771       5.0      NaN         25.0             NaN      NaN
# 2/10/20  42168       NaN      NaN         27.0             NaN      NaN
# 2/11/20  44268       5.0      NaN         28.0             NaN      NaN
# 2/12/20  44699       NaN      NaN         28.0             NaN      NaN
# 2/13/20  59831       6.0      NaN          NaN             NaN      NaN
# 2/14/20  66183       NaN      NaN          NaN             NaN      NaN
# 2/15/20  68346       NaN      NaN         28.0             NaN      NaN
# 2/16/20  70357       NaN      NaN         29.0             NaN      NaN
# 2/17/20  71988       NaN      NaN         30.0             NaN      NaN
# 2/18/20  72345       NaN      NaN         31.0             NaN      NaN
# 2/19/20  73594       NaN      NaN          NaN             NaN      2.0
# 2/20/20  73602       NaN      NaN        104.0             NaN      5.0
# ...        ...       ...      ...          ...             ...      ...
# 2/28/20  74545      37.0    888.0       2337.0             NaN    388.0
# 2/29/20  74606      42.0   1128.0       3150.0             NaN    593.0
# 3/1/20   74863      45.0   1694.0       3736.0             NaN    978.0
# 3/2/20   74980      54.0   2036.0       4335.0             NaN   1501.0
# 3/3/20   75133      62.0   2502.0       5186.0             NaN   2336.0
# 3/4/20   75471      88.0   3089.0       5621.0             NaN   2922.0
# 3/5/20   76112     142.0   3858.0       6088.0             NaN   3513.0
# 3/6/20   76516     168.0   4636.0       6593.0             NaN   4747.0
# 3/7/20   76600     203.0   5883.0       7041.0             NaN   5823.0
# 3/8/20   76741     311.0   7375.0       7314.0             NaN   6566.0
# 3/9/20   76769     387.0   9172.0       7478.0             NaN   7161.0
# 3/10/20  76902     959.0  10149.0          NaN             NaN      NaN
# 3/11/20  76919    1200.0  12462.0       7755.0             3.0   9000.0
# 3/12/20  76987    1554.0      NaN       7869.0             NaN  10075.0
# 3/13/20  77201       NaN      NaN          NaN             NaN      NaN
# 3/14/20  77474    2617.0  21157.0       8086.0           459.0  12729.0
# 3/15/20  77817    2877.0      NaN       8162.0          1141.0  13938.0
# 3/16/20  77900    4612.0  27980.0       8236.0          1550.0  14991.0
# 3/17/20  78330    6287.0  31506.0       8320.0          1953.0  16169.0
# 3/18/20  78388    7447.0  35713.0       8413.0          2635.0  17361.0
# 3/19/20  78619   13604.0  41035.0       8565.0          2715.0  18407.0
# 3/20/20  78995   19057.0  47021.0       8652.0          3998.0  19644.0
# 3/21/20  79455   25335.0  53578.0       8799.0          5052.0  20610.0
# 3/22/20  79465   33746.0  59138.0       8897.0          5741.0  21638.0
# 3/23/20  79538   43667.0  63927.0       8961.0          6726.0  23049.0
# 3/24/20  79574   53740.0  69176.0       9037.0          8164.0  24811.0
# 3/25/20  79588   65778.0  74386.0       9137.0          9640.0  27017.0
# 3/26/20  79749   83836.0  80589.0       9241.0         11812.0  29406.0
# 3/27/20  79771  101657.0  86498.0       9332.0         14745.0  32332.0
# 3/28/20  80921  121478.0  92472.0       9478.0         17312.0  35408.0
#
# [67 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

dfChina.plot(grid = True);
dfUS.plot(grid = True);
dfIt.plot(grid = True);
dfNZ.plot(grid = True);
dfSK.plot(grid = True);
dfUK.plot(grid = True);
dfI.plot(grid = True);
dfS.plot(grid = True);
dfIND.plot(grid=True);
dfP.plot(grid = True);
dfdata.plot(grid = True);
