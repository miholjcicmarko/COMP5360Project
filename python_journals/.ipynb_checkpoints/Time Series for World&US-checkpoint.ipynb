# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/CLEANCDRData.csv")
data
# Out:
#       Country/Region Last Update  Confirmed  Deaths  Recovered
# 0              China     1/22/20          1       0          0
# 1              China     1/22/20         14       0          0
# 2              China     1/22/20          6       0          0
# 3              China     1/22/20          1       0          0
# 4              China     1/22/20          0       0          0
# 5              China     1/22/20         26       0          0
# 6              China     1/22/20          2       0          0
# 7              China     1/22/20          1       0          0
# 8              China     1/22/20          4       0          0
# 9              China     1/22/20          1       0          0
# 10             China     1/22/20          0       0          0
# 11             China     1/22/20          5       0          0
# 12             China     1/22/20        444      17         28
# 13             China     1/22/20          4       0          0
# ...

# %%
from datetime import datetime
groupDate = data.groupby("Last Update")
df1 = groupDate.count()

df1 = list(df1.index.values)
df1.sort(key = lambda date: datetime.strptime(date, '%m/%d/%y'))

dfDate = pd.DataFrame(df1)
dfDate
    
# making data frame  
#data = pd.read_csv("nba.csv")  
  
# calling head() method   
# storing in new variable  
#data_top = data.head()  
    
#list(data_top.index.values)

#groupyear = filterrows.groupby("year")
#counts = groupyear["title"].count()
# Out:
#           0
# 0   1/22/20
# 1   1/23/20
# 2   1/24/20
# 3   1/25/20
# 4   1/26/20
# 5   1/27/20
# 6   1/28/20
# 7   1/29/20
# 8   1/30/20
# 9   1/31/20
# 10   2/1/20
# 11   2/2/20
# 12   2/3/20
# 13   2/4/20
# 14   2/5/20
# 15   2/6/20
# 16   2/7/20
# 17   2/8/20
# 18   2/9/20
# 19  2/10/20
# 20  2/11/20
# 21  2/12/20
# 22  2/13/20
# 23  2/14/20
# 24  2/15/20
# 25  2/16/20
# 26  2/17/20
# 27  2/18/20
# 28  2/19/20
# 29  2/20/20
# ..      ...
# 37  2/28/20
# 38  2/29/20
# 39   3/1/20
# 40   3/2/20
# 41   3/3/20
# 42   3/4/20
# 43   3/5/20
# 44   3/6/20
# 45   3/7/20
# 46   3/8/20
# 47   3/9/20
# 48  3/10/20
# 49  3/11/20
# 50  3/12/20
# 51  3/13/20
# 52  3/14/20
# 53  3/15/20
# 54  3/16/20
# 55  3/17/20
# 56  3/18/20
# 57  3/19/20
# 58  3/20/20
# 59  3/21/20
# 60  3/22/20
# 61  3/23/20
# 62  3/24/20
# 63  3/25/20
# 64  3/26/20
# 65  3/27/20
# 66  3/28/20
#
# [67 rows x 1 columns]

# %%
dataChina = data[data["Country/Region"] == "China"]  
dataChina
groupChina = dataChina.groupby("Last Update")
dChina = groupChina.sum()
dChina = list(dChina["Confirmed"].values)
dChina.sort()
dChina

dfData = pd.DataFrame({"China": dChina})
dfData = pd.concat([dfDate,dfData], axis=1, sort = False)
dfData = dfData.rename(columns={0: "Date"})
dfData = dfData.set_index('Date')
dfData

#ChinaCon = {"China": }
#print(ChinaCon)
#dfD = pd.DataFrame({"China": dChina["Confirmed"].values})
#dfD = pd.concat([df,dfD], axis=1, sort = False)
#dfD = dfD.rename(columns={0: "Date"})
#dfD = dfD.set_index('Date')
#dfD
# Out:
#          China
# Date
# 1/22/20    547
# 1/23/20    639
# 1/24/20    916
# 1/25/20   1399
# 1/26/20   2062
# 1/27/20   2863
# 1/28/20   5494
# 1/29/20   6070
# 1/30/20   8124
# 1/31/20   9783
# 2/1/20   11842
# 2/2/20   16606
# 2/3/20   19692
# 2/4/20   23679
# 2/5/20   27374
# 2/6/20   30490
# 2/7/20   34056
# 2/8/20   36759
# 2/9/20   39771
# 2/10/20  42168
# 2/11/20  44268
# 2/12/20  44699
# 2/13/20  59831
# 2/14/20  66183
# 2/15/20  68346
# 2/16/20  70357
# 2/17/20  71988
# 2/18/20  72345
# 2/19/20  73594
# 2/20/20  73602
# ...        ...
# 2/28/20  74545
# 2/29/20  74606
# 3/1/20   74863
# 3/2/20   74980
# 3/3/20   75133
# 3/4/20   75471
# 3/5/20   76112
# 3/6/20   76516
# 3/7/20   76600
# 3/8/20   76741
# 3/9/20   76769
# 3/10/20  76902
# 3/11/20  76919
# 3/12/20  76987
# 3/13/20  77201
# 3/14/20  77474
# 3/15/20  77817
# 3/16/20  77900
# 3/17/20  78330
# 3/18/20  78388
# 3/19/20  78619
# 3/20/20  78995
# 3/21/20  79455
# 3/22/20  79465
# 3/23/20  79538
# 3/24/20  79574
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

dfData.plot(grid = True);

# %%
#adj_close = pd.DataFrame({ "AAPL": AAPL["Adj Close"],
#                           "MSFT": MSFT["Adj Close"],
#                           "GOOG": GOOG["Adj Close"]})
