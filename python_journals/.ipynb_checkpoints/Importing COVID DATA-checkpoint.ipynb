# %%
import requests
import pandas as pd

dates = ['01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28', '01-29', '01-30', '01-31']

df = pd.DataFrame()

for x in range(len(dates)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates[x] + '-2020.csv'
    response = requests.get(str(url))
        
    df1 = pd.read_csv(url)
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[0:7] + "20")
    states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
    abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

    for x in range(51):
        df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])
    
        df1["Province/State"] = df1["Province/State"].replace("Chicago", "IL")    
    df = df.append(df1, ignore_index = True)

#df

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv'
response = requests.get(url)

df1 = pd.read_csv(url)
df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[0:1] + "/0" + x[2:6] + "20")
mask = df1['Last Update'] == "02/01/2020"
df1 = df1.loc[mask]

df1["Province/State"] = df1["Province/State"].fillna("none") 
df1['Province/State'] = df1['Province/State'].apply(lambda x : x[-2:])
df = df.append(df1, ignore_index = True)
#df

# %%
dates2 = ['02-02', '02-03', '02-04', '02-05', '02-06', '02-07', '02-08', '02-09', '02-10', '02-11', '02-12',
        '02-13', '02-14', '02-15', '02-16', '02-17', '02-18', '02-19', '02-20', '02-21', '02-22', '02-23',
        '02-24', '02-25', '02-26', '02-27', '02-28', '02-29']

for x in range(len(dates2)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates2[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:10] + "/" + "2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]

    df1["Province/State"] = df1["Province/State"].replace("Omaha, NE (From Diamond Princess)", "NE")
    df1["Province/State"] = df1["Province/State"].replace("Travis, CA (From Diamond Princess)", "CA")
    df1["Province/State"] = df1["Province/State"].replace("Lackland, TX (From Diamond Princess)", "TX")

    df1["Province/State"] = df1["Province/State"].fillna("none") 
    df1['Province/State'] = df1['Province/State'].apply(lambda x : x[-2:])

    df = df.append(df1, ignore_index = True)

#df

# %%
dates3 = ['03-01', '03-02', '03-03', '03-04', '03-05', '03-06', '03-07', '03-08', '03-09']

for x in range(len(dates3)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates3[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1 = df1[["Province/State", "Country/Region",  "Last Update", "Confirmed", "Deaths", "Recovered"]]
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:7] + "/0" + x[9] + "/" + "2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]

    df1["Province/State"] = df1["Province/State"].replace("Omaha, NE (From Diamond Princess)", "NE")
    df1["Province/State"] = df1["Province/State"].replace("Travis, CA (From Diamond Princess)", "CA")
    df1["Province/State"] = df1["Province/State"].replace("Lackland, TX (From Diamond Princess)", "TX")
    df1["Province/State"] = df1["Province/State"].replace("Washington, D.C.", "DC")

    df1["Province/State"] = df1["Province/State"].fillna("none") 
    df1['Province/State'] = df1['Province/State'].apply(lambda x : x[-2:])

    df = df.append(df1, ignore_index = True)
    
#df

# %%
dates4 = ['03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', 
        '03-18', '03-19', '03-20', '03-21']

for x in range(len(dates4)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates4[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1 = df1[["Province/State", "Country/Region",  "Last Update", "Confirmed", "Deaths", "Recovered"]]
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:10] + "/" + "2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]
    states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
    abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

    for x in range(51):
        df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])
    
    df = df.append(df1, ignore_index = True)
    
#df

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv'
response = requests.get(url)

df1 = pd.read_csv(url)
df1 = df1.rename(columns={"Province_State": "Province/State", "Country_Region": "Country/Region", "Last_Update": "Last Update"})
df1 = df1[["Province/State", "Country/Region", "Last Update", "Confirmed", "Deaths", "Recovered"]]

df1['Last Update'] = df1['Last Update'].apply(lambda x :"0" + x[0:7] + "20")
mask = df1['Last Update'] == df1['Last Update'][0]
df1 = df1.loc[mask]

states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

for x in range(51):
    df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])

df = df.append(df1, ignore_index = True)
#df

# %%
dates5 = ['03-23', '03-24', '03-25', '03-26', '03-27', '03-28', 
        '03-29', '03-30', '03-31', '04-01']

for x in range(len(dates5)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates5[x] + '-2020.csv'
    response = requests.get(url)
    
    df1 = pd.read_csv(url)
    df1 = df1.rename(columns={"Province_State": "Province/State", "Country_Region": "Country/Region", "Last_Update": "Last Update"})
    df1 = df1[["Province/State", "Country/Region", "Last Update", "Confirmed", "Deaths", "Recovered"]]

    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:10] + "/2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]
    states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
    abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

    for x in range(51):
        df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])

    df = df.append(df1, ignore_index = True)
    
#df
# Out:
#        Province/State        Country/Region Last Update  Confirmed  Deaths  \
# 0               Anhui        Mainland China  01/22/2020        1.0     NaN
# 1             Beijing        Mainland China  01/22/2020       14.0     NaN
# 2           Chongqing        Mainland China  01/22/2020        6.0     NaN
# 3              Fujian        Mainland China  01/22/2020        1.0     NaN
# 4               Gansu        Mainland China  01/22/2020        NaN     NaN
# 5           Guangdong        Mainland China  01/22/2020       26.0     NaN
# 6             Guangxi        Mainland China  01/22/2020        2.0     NaN
# 7             Guizhou        Mainland China  01/22/2020        1.0     NaN
# 8              Hainan        Mainland China  01/22/2020        4.0     NaN
# 9               Hebei        Mainland China  01/22/2020        1.0     NaN
# 10       Heilongjiang        Mainland China  01/22/2020        NaN     NaN
# 11              Henan        Mainland China  01/22/2020        5.0     NaN
# 12          Hong Kong             Hong Kong  01/22/2020        NaN     NaN
# 13              Hubei        Mainland China  01/22/2020      444.0    17.0
# 14              Hunan        Mainland China  01/22/2020        4.0     NaN
# 15     Inner Mongolia        Mainland China  01/22/2020        NaN     NaN
# 16            Jiangsu        Mainland China  01/22/2020        1.0     NaN
# 17            Jiangxi        Mainland China  01/22/2020        2.0     NaN
# 18              Jilin        Mainland China  01/22/2020        NaN     NaN
# 19           Liaoning        Mainland China  01/22/2020        2.0     NaN
# 20              Macau                 Macau  01/22/2020        1.0     NaN
# 21            Ningxia        Mainland China  01/22/2020        1.0     NaN
# 22            Qinghai        Mainland China  01/22/2020        NaN     NaN
# 23            Shaanxi        Mainland China  01/22/2020        NaN     NaN
# 24           Shandong        Mainland China  01/22/2020        2.0     NaN
# 25           Shanghai        Mainland China  01/22/2020        9.0     NaN
# 26             Shanxi        Mainland China  01/22/2020        1.0     NaN
# 27            Sichuan        Mainland China  01/22/2020        5.0     NaN
# 28             Taiwan                Taiwan  01/22/2020        1.0     NaN
# 29            Tianjin        Mainland China  01/22/2020        4.0     NaN
# ...               ...                   ...         ...        ...     ...
# 40223             NaN              Slovakia  04/01/2020      400.0     1.0
# 40224             NaN              Slovenia  04/01/2020      841.0    15.0
# 40225             NaN               Somalia  04/01/2020        5.0     0.0
# 40226             NaN          South Africa  04/01/2020     1380.0     5.0
# 40227             NaN                 Spain  04/01/2020   104118.0  9387.0
# 40228             NaN             Sri Lanka  04/01/2020      146.0     3.0
# 40229             NaN                 Sudan  04/01/2020        7.0     2.0
# 40230             NaN              Suriname  04/01/2020       10.0     0.0
# 40231             NaN                Sweden  04/01/2020     4947.0   239.0
# 40232             NaN           Switzerland  04/01/2020    17768.0   488.0
# 40233             NaN                 Syria  04/01/2020       10.0     2.0
# 40234             NaN               Taiwan*  04/01/2020      329.0     5.0
# 40235             NaN              Tanzania  04/01/2020       20.0     1.0
# 40236             NaN              Thailand  04/01/2020     1771.0    12.0
# 40237             NaN           Timor-Leste  04/01/2020        1.0     0.0
# 40238             NaN                  Togo  04/01/2020       36.0     2.0
# 40239             NaN   Trinidad and Tobago  04/01/2020       90.0     5.0
# 40240             NaN               Tunisia  04/01/2020      423.0    12.0
# 40241             NaN                Turkey  04/01/2020    15679.0   277.0
# 40242             NaN                Uganda  04/01/2020       44.0     0.0
# 40243             NaN               Ukraine  04/01/2020      794.0    20.0
# 40244             NaN  United Arab Emirates  04/01/2020      814.0     8.0
# 40245             NaN        United Kingdom  04/01/2020    29474.0  2352.0
# 40246             NaN               Uruguay  04/01/2020      338.0     2.0
# 40247             NaN            Uzbekistan  04/01/2020      181.0     2.0
# 40248             NaN             Venezuela  04/01/2020      143.0     3.0
# 40249             NaN               Vietnam  04/01/2020      218.0     0.0
# 40250             NaN    West Bank and Gaza  04/01/2020      134.0     1.0
# 40251             NaN                Zambia  04/01/2020       36.0     0.0
# 40252             NaN              Zimbabwe  04/01/2020        8.0     1.0
#
#        Recovered
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13          28.0
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 40223        3.0
# 40224       10.0
# 40225        1.0
# 40226       50.0
# 40227    22647.0
# 40228       21.0
# 40229        2.0
# 40230        0.0
# 40231      103.0
# 40232     2967.0
# 40233        0.0
# 40234       39.0
# 40235        1.0
# 40236      505.0
# 40237        0.0
# 40238       10.0
# 40239        1.0
# 40240        5.0
# 40241      333.0
# 40242        0.0
# 40243       13.0
# 40244       61.0
# 40245      135.0
# 40246       41.0
# 40247       12.0
# 40248       41.0
# 40249       63.0
# 40250       18.0
# 40251        0.0
# 40252        0.0
#
# [40253 rows x 6 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/CDRdata.csv', index = False)

# %%
import requests
import pandas as pd

dates = ['03-01', '03-02', '03-03', '03-04', '03-05', '03-06', '03-07', '03-08', '03-09']

df = pd.DataFrame()

for x in range(len(dates)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:7] + "/0" + x[9] + "/" + "2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]

    df1["Province/State"] = df1["Province/State"].replace("Omaha, NE (From Diamond Princess)", "NE")
    df1["Province/State"] = df1["Province/State"].replace("Travis, CA (From Diamond Princess)", "CA")
    df1["Province/State"] = df1["Province/State"].replace("Lackland, TX (From Diamond Princess)", "TX")
    df1["Province/State"] = df1["Province/State"].replace("Washington, D.C.", "DC")

    df1["Province/State"] = df1["Province/State"].fillna("none") 
    df1['Province/State'] = df1['Province/State'].apply(lambda x : x[-2:])

    df = df.append(df1, ignore_index = True)
    
df
# Out:
#     Province/State    Country/Region Last Update  Confirmed  Deaths  \
# 0               ei    Mainland China  03/01/2020      66907    2761
# 1               ne       South Korea  03/01/2020       3736      17
# 2               ne             Italy  03/01/2020       1694      34
# 3               ng    Mainland China  03/01/2020       1349       7
# 4               an    Mainland China  03/01/2020       1272      22
# 5               ng    Mainland China  03/01/2020       1205       1
# 6               an    Mainland China  03/01/2020       1018       4
# 7               ui    Mainland China  03/01/2020        990       6
# 8               ne              Iran  03/01/2020        978      54
# 9               xi    Mainland China  03/01/2020        935       1
# 10              ng    Mainland China  03/01/2020        758       6
# 11              su    Mainland China  03/01/2020        631       0
# 12              ng    Mainland China  03/01/2020        576       6
# 13              an    Mainland China  03/01/2020        538       3
# 14              ng    Mainland China  03/01/2020        480      13
# 15              ng    Mainland China  03/01/2020        413       8
# 16              ai    Mainland China  03/01/2020        337       3
# 17              ei    Mainland China  03/01/2020        318       6
# 18              an    Mainland China  03/01/2020        296       1
# 19              ne             Japan  03/01/2020        256       6
# 20              xi    Mainland China  03/01/2020        252       2
# 21              xi    Mainland China  03/01/2020        245       1
# 22              an    Mainland China  03/01/2020        174       2
# 23              an    Mainland China  03/01/2020        168       5
# 24              in    Mainland China  03/01/2020        136       3
# 25              xi    Mainland China  03/01/2020        133       0
# 26              ne            France  03/01/2020        130       2
# 27              ne           Germany  03/01/2020        130       0
# 28              ng    Mainland China  03/01/2020        122       1
# 29              ne         Singapore  03/01/2020        106       0
# ..             ...               ...         ...        ...     ...
# 875             CA                US  03/09/2020          4       0
# 876             NY                US  03/09/2020          4       0
# 877             ec            Canada  03/09/2020          3       0
# 878             FL                US  03/09/2020          3       0
# 879             GA                US  03/09/2020          3       0
# 880             NE                US  03/09/2020          3       0
# 881             IA                US  03/09/2020          3       0
# 882             CA                US  03/09/2020          3       0
# 883             ne           Albania  03/09/2020          2       0
# 884             ne            Cyprus  03/09/2020          2       0
# 885             ne           Nigeria  03/09/2020          2       0
# 886             ne        St. Martin  03/09/2020          2       0
# 887             KY                US  03/09/2020          2       0
# 888             IN                US  03/09/2020          2       0
# 889             HI                US  03/09/2020          2       0
# 890             FL                US  03/09/2020          2       0
# 891             ne            Brunei  03/09/2020          1       0
# 892             ne           Moldova  03/09/2020          1       0
# 893             ne  Saint Barthelemy  03/09/2020          1       0
# 894             VT                US  03/09/2020          1       0
# 895             MN                US  03/09/2020          1       0
# 896             FL                US  03/09/2020          1       0
# 897             GA                US  03/09/2020          1       0
# 898             TX                US  03/09/2020          1       0
# 899             WA                US  03/09/2020          1       1
# 900             KY                US  03/09/2020          1       0
# 901             LA                US  03/09/2020          1       0
# 902             NH                US  03/09/2020          1       0
# 903             CA                US  03/09/2020          1       0
# 904             SC                US  03/09/2020          1       0
#
#      Recovered  Latitude  Longitude
# 0        31536   30.9756   112.2707
# 1           30   36.0000   128.0000
# 2           83   43.0000    12.0000
# 3         1016   23.3417   113.4244
# 4         1198   33.8820   113.6140
# 5         1046   29.1832   120.0934
# 6          866   27.6104   111.7088
# 7          873   31.8257   117.2264
# 8          175   32.0000    53.0000
# 9          831   27.6140   115.7221
# 10         443   36.3427   118.1498
# 11         536   32.9711   119.4550
# 12         450   30.0572   107.8740
# 13         365   30.6171   102.7103
# 14         342   47.8620   127.7615
# 15         276   40.1824   116.4142
# 16         290   31.2020   121.4491
# 17         294   38.0428   114.5149
# 18         247   26.0789   117.9874
# 19          32   36.0000   138.0000
# 20         181   23.8298   108.7881
# 21         208   35.1917   108.8701
# 22         163   24.9740   101.4870
# 23         149   19.1959   109.7453
# 24         111   39.3054   117.3230
# 25         116   37.5777   112.2922
# 26          12   47.0000     2.0000
# 27          16   51.0000     9.0000
# 28         103   41.2956   122.6085
# 29          72    1.2833   103.8333
# ..         ...       ...        ...
# 875          0   33.7879  -117.8531
# 876          0   41.1489   -73.9830
# 877          0   52.9399   -73.5491
# 878          0   26.1901   -80.3659
# 879          0   33.8999   -84.5641
# 880          0   41.3148   -96.1951
# 881          0   41.6699   -91.5984
# 882          0   38.5780  -122.9888
# 883          0   41.1533    20.1683
# 884          0   35.1264    33.4299
# 885          0    9.0820     8.6753
# 886          0   18.0708   -63.0501
# 887          0   38.4333   -84.3542
# 888          0   39.8065   -86.5401
# 889          0   21.3070  -157.8584
# 890          0   27.4799   -82.3452
# 891          0    4.5353   114.7277
# 892          0   47.4116    28.3699
# 893          0   17.9000   -62.8333
# 894          0   43.0279   -73.1350
# 895          0   44.8254   -93.7842
# 896          0   26.8946   -81.9098
# 897          0   34.2515   -84.4803
# 898          0   33.1795   -96.4930
# 899          0   47.1981  -119.3732
# 900          0   38.1938   -85.6435
# 901          0   29.6499   -90.1121
# 902          0   42.9931   -71.0498
# 903          0   40.7909  -121.8474
# 904          0   34.8606   -81.9535
#
# [905 rows x 8 columns]

# %%
dates2 = ['03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17','03-18', '03-19', 
          '03-20', '03-21']

for x in range(len(dates2)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates2[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:10] + "/" + "2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]
    states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
    abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

    for x in range(51):
        df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])
    
    df = df.append(df1, ignore_index = True)
    
df
# Out:
#                     Province/State    Country/Region Last Update  Confirmed  \
# 0                               ei    Mainland China  03/01/2020      66907
# 1                               ne       South Korea  03/01/2020       3736
# 2                               ne             Italy  03/01/2020       1694
# 3                               ng    Mainland China  03/01/2020       1349
# 4                               an    Mainland China  03/01/2020       1272
# 5                               ng    Mainland China  03/01/2020       1205
# 6                               an    Mainland China  03/01/2020       1018
# 7                               ui    Mainland China  03/01/2020        990
# 8                               ne              Iran  03/01/2020        978
# 9                               xi    Mainland China  03/01/2020        935
# 10                              ng    Mainland China  03/01/2020        758
# 11                              su    Mainland China  03/01/2020        631
# 12                              ng    Mainland China  03/01/2020        576
# 13                              an    Mainland China  03/01/2020        538
# 14                              ng    Mainland China  03/01/2020        480
# 15                              ng    Mainland China  03/01/2020        413
# 16                              ai    Mainland China  03/01/2020        337
# 17                              ei    Mainland China  03/01/2020        318
# 18                              an    Mainland China  03/01/2020        296
# 19                              ne             Japan  03/01/2020        256
# 20                              xi    Mainland China  03/01/2020        252
# 21                              xi    Mainland China  03/01/2020        245
# 22                              an    Mainland China  03/01/2020        174
# 23                              an    Mainland China  03/01/2020        168
# 24                              in    Mainland China  03/01/2020        136
# 25                              xi    Mainland China  03/01/2020        133
# 26                              ne            France  03/01/2020        130
# 27                              ne           Germany  03/01/2020        130
# 28                              ng    Mainland China  03/01/2020        122
# 29                              ne         Singapore  03/01/2020        106
# ...                            ...               ...         ...        ...
# 2924                           NaN        Kyrgyzstan  03/21/2020         14
# 2925                           NaN         Mauritius  03/21/2020         14
# 2926                           NaN            Monaco  03/21/2020         11
# 2927                           NaN          Mongolia  03/21/2020         10
# 2928  Australian Capital Territory         Australia  03/21/2020          9
# 2929                            WV                US  03/21/2020          8
# 2930                           NaN           Mayotte  03/21/2020          7
# 2931                           NaN          Barbados  03/21/2020          6
# 2932     Newfoundland and Labrador            Canada  03/21/2020          6
# 2933  United States Virgin Islands                US  03/21/2020          6
# 2934                           NaN      Bahamas, The  03/21/2020          4
# 2935                 New Caledonia            France  03/21/2020          4
# 2936                           NaN             Gabon  03/21/2020          4
# 2937                           NaN        Cabo Verde  03/21/2020          3
# 2938                           NaN       El Salvador  03/21/2020          3
# 2939                           NaN           Liberia  03/21/2020          3
# 2940                           NaN          Zimbabwe  03/21/2020          3
# 2941                           NaN            Angola  03/21/2020          2
# 2942                           NaN            Guinea  03/21/2020          2
# 2943                           NaN             Haiti  03/21/2020          2
# 2944                           NaN         Nicaragua  03/21/2020          2
# 2945                       Bermuda    United Kingdom  03/21/2020          2
# 2946         Northwest Territories            Canada  03/21/2020          1
# 2947                           NaN        Cape Verde  03/21/2020          1
# 2948                           NaN              Chad  03/21/2020          1
# 2949                           NaN        East Timor  03/21/2020          1
# 2950                           NaN           Eritrea  03/21/2020          1
# 2951                           NaN  Papua New Guinea  03/21/2020          1
# 2952                            US                US  03/21/2020          1
# 2953                           NaN            Uganda  03/21/2020          1
#
#       Deaths  Recovered  Latitude  Longitude
# 0       2761      31536   30.9756   112.2707
# 1         17         30   36.0000   128.0000
# 2         34         83   43.0000    12.0000
# 3          7       1016   23.3417   113.4244
# 4         22       1198   33.8820   113.6140
# 5          1       1046   29.1832   120.0934
# 6          4        866   27.6104   111.7088
# 7          6        873   31.8257   117.2264
# 8         54        175   32.0000    53.0000
# 9          1        831   27.6140   115.7221
# 10         6        443   36.3427   118.1498
# 11         0        536   32.9711   119.4550
# 12         6        450   30.0572   107.8740
# 13         3        365   30.6171   102.7103
# 14        13        342   47.8620   127.7615
# 15         8        276   40.1824   116.4142
# 16         3        290   31.2020   121.4491
# 17         6        294   38.0428   114.5149
# 18         1        247   26.0789   117.9874
# 19         6         32   36.0000   138.0000
# 20         2        181   23.8298   108.7881
# 21         1        208   35.1917   108.8701
# 22         2        163   24.9740   101.4870
# 23         5        149   19.1959   109.7453
# 24         3        111   39.3054   117.3230
# 25         0        116   37.5777   112.2922
# 26         2         12   47.0000     2.0000
# 27         0         16   51.0000     9.0000
# 28         1        103   41.2956   122.6085
# 29         0         72    1.2833   103.8333
# ...      ...        ...       ...        ...
# 2924       0          0   41.2044    74.7661
# 2925       1          0  -20.3484    57.5522
# 2926       0          0   43.7384     7.4246
# 2927       0          0   46.8625   103.8467
# 2928       0          0  -35.4735   149.0124
# 2929       0          0   38.4912   -80.9545
# 2930       0          0  -12.8275    45.1662
# 2931       0          0   13.1939   -59.5432
# 2932       0          0   53.1355   -57.6604
# 2933       0          0   18.3358   -64.8963
# 2934       0          0   25.0343   -77.3963
# 2935       0          0  -20.9043   165.6180
# 2936       1          0   -0.8037    11.6094
# 2937       0          0   16.5388   -23.0418
# 2938       0          0   13.7942   -88.8965
# 2939       0          0    6.4281    -9.4295
# 2940       0          0  -19.0154    29.1549
# 2941       0          0  -11.2027    17.8739
# 2942       0          0    9.9456    -9.6966
# 2943       0          0   18.9712   -72.2852
# 2944       0          0   12.8654   -85.2072
# 2945       0          0   32.3078   -64.7505
# 2946       0          0   64.8255  -124.8457
# 2947       0          0   15.1111   -23.6167
# 2948       0          0   15.4542    18.7322
# 2949       0          0   -8.5500   125.5600
# 2950       0          0   15.1794    39.7823
# 2951       0          0   -6.3150   143.9555
# 2952       0        171   37.0902   -95.7129
# 2953       0          0    1.0000    32.0000
#
# [2954 rows x 8 columns]

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv'
response = requests.get(url)

df1 = pd.read_csv(url)
df1 = df1.rename(columns={"Province_State": "Province/State", "Country_Region": "Country/Region", "Last_Update": "Last Update", "Lat":"Latitude", "Long_":"Longitude"})
df1 = df1[["Province/State", "Country/Region", "Last Update", "Confirmed", "Deaths", "Recovered", "Latitude", "Longitude"]]

df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[0:7] + "20")
mask = df1['Last Update'] == df1['Last Update'][0]
df1 = df1.loc[mask]

states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

for x in range(51):
    df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])

df = df.append(df1, ignore_index = True)
df
# Out:
#      Province/State                    Country/Region Last Update  Confirmed  \
# 0                ei                    Mainland China  03/01/2020      66907
# 1                ne                       South Korea  03/01/2020       3736
# 2                ne                             Italy  03/01/2020       1694
# 3                ng                    Mainland China  03/01/2020       1349
# 4                an                    Mainland China  03/01/2020       1272
# 5                ng                    Mainland China  03/01/2020       1205
# 6                an                    Mainland China  03/01/2020       1018
# 7                ui                    Mainland China  03/01/2020        990
# 8                ne                              Iran  03/01/2020        978
# 9                xi                    Mainland China  03/01/2020        935
# 10               ng                    Mainland China  03/01/2020        758
# 11               su                    Mainland China  03/01/2020        631
# 12               ng                    Mainland China  03/01/2020        576
# 13               an                    Mainland China  03/01/2020        538
# 14               ng                    Mainland China  03/01/2020        480
# 15               ng                    Mainland China  03/01/2020        413
# 16               ai                    Mainland China  03/01/2020        337
# 17               ei                    Mainland China  03/01/2020        318
# 18               an                    Mainland China  03/01/2020        296
# 19               ne                             Japan  03/01/2020        256
# 20               xi                    Mainland China  03/01/2020        252
# 21               xi                    Mainland China  03/01/2020        245
# 22               an                    Mainland China  03/01/2020        174
# 23               an                    Mainland China  03/01/2020        168
# 24               in                    Mainland China  03/01/2020        136
# 25               xi                    Mainland China  03/01/2020        133
# 26               ne                            France  03/01/2020        130
# 27               ne                           Germany  03/01/2020        130
# 28               ng                    Mainland China  03/01/2020        122
# 29               ne                         Singapore  03/01/2020        106
# ...             ...                               ...         ...        ...
# 6325            NaN                             Benin  03/22/2020          2
# 6326        Bermuda                    United Kingdom  03/22/2020          2
# 6327            NaN                            Bhutan  03/22/2020          2
# 6328            NaN                              Fiji  03/22/2020          2
# 6329            NaN                            Guinea  03/22/2020          2
# 6330            NaN                             Haiti  03/22/2020          2
# 6331            NaN                        Mauritania  03/22/2020          2
# 6332            NaN                         Nicaragua  03/22/2020          2
# 6333            NaN                             Niger  03/22/2020          2
# 6334            NaN                       Saint Lucia  03/22/2020          2
# 6335            NaN                             Nepal  03/22/2020          1
# 6336            NaN               Antigua and Barbuda  03/22/2020          1
# 6337            NaN                              Chad  03/22/2020          1
# 6338            NaN                          Djibouti  03/22/2020          1
# 6339            NaN                          Dominica  03/22/2020          1
# 6340            NaN                           Eritrea  03/22/2020          1
# 6341            NaN                            Gambia  03/22/2020          1
# 6342            NaN                           Grenada  03/22/2020          1
# 6343            NaN                          Holy See  03/22/2020          1
# 6344     Montserrat                    United Kingdom  03/22/2020          1
# 6345            NaN                        Mozambique  03/22/2020          1
# 6346            NaN                  Papua New Guinea  03/22/2020          1
# 6347            NaN  Saint Vincent and the Grenadines  03/22/2020          1
# 6348   Sint Maarten                       Netherlands  03/22/2020          1
# 6349            NaN                           Somalia  03/22/2020          1
# 6350            NaN                             Syria  03/22/2020          1
# 6351            NaN                       Timor-Leste  03/22/2020          1
# 6352            NaN                            Uganda  03/22/2020          1
# 6353             DC                                US  03/22/2020        102
# 6354             WA                                US  03/22/2020          1
#
#       Deaths  Recovered   Latitude   Longitude
# 0       2761      31536  30.975600  112.270700
# 1         17         30  36.000000  128.000000
# 2         34         83  43.000000   12.000000
# 3          7       1016  23.341700  113.424400
# 4         22       1198  33.882000  113.614000
# 5          1       1046  29.183200  120.093400
# 6          4        866  27.610400  111.708800
# 7          6        873  31.825700  117.226400
# 8         54        175  32.000000   53.000000
# 9          1        831  27.614000  115.722100
# 10         6        443  36.342700  118.149800
# 11         0        536  32.971100  119.455000
# 12         6        450  30.057200  107.874000
# 13         3        365  30.617100  102.710300
# 14        13        342  47.862000  127.761500
# 15         8        276  40.182400  116.414200
# 16         3        290  31.202000  121.449100
# 17         6        294  38.042800  114.514900
# 18         1        247  26.078900  117.987400
# 19         6         32  36.000000  138.000000
# 20         2        181  23.829800  108.788100
# 21         1        208  35.191700  108.870100
# 22         2        163  24.974000  101.487000
# 23         5        149  19.195900  109.745300
# 24         3        111  39.305400  117.323000
# 25         0        116  37.577700  112.292200
# 26         2         12  47.000000    2.000000
# 27         0         16  51.000000    9.000000
# 28         1        103  41.295600  122.608500
# 29         0         72   1.283300  103.833300
# ...      ...        ...        ...         ...
# 6325       0          0   9.307700    2.315800
# 6326       0          0  32.307800  -64.750500
# 6327       0          0  27.514200   90.433600
# 6328       0          0 -17.713400  178.065000
# 6329       0          0   9.945600   -9.696600
# 6330       0          0  18.971200  -72.285200
# 6331       0          0  21.007900   10.940800
# 6332       0          0  12.865416  -85.207229
# 6333       0          0  17.607789    8.081666
# 6334       0          0  13.909400  -60.978900
# 6335       0          1  28.166700   84.250000
# 6336       0          0  17.060800  -61.796400
# 6337       0          0  15.454200   18.732200
# 6338       0          0  11.825100   42.590300
# 6339       0          0  15.415000  -61.371000
# 6340       0          0  15.179400   39.782300
# 6341       0          0  13.443200  -15.310100
# 6342       0          0  12.116500  -61.679000
# 6343       0          0  41.902900   12.453400
# 6344       0          0  16.742498  -62.187366
# 6345       0          0 -18.665695   35.529562
# 6346       0          0  -6.314993  143.955550
# 6347       0          0  12.984300  -61.287200
# 6348       0          0  18.042500  -63.054800
# 6349       0          0   5.152149   46.199616
# 6350       0          0  34.802075   38.996815
# 6351       0          0  -8.874217  125.727539
# 6352       0          0   1.373333   32.290275
# 6353       2          0  38.904178  -77.016560
# 6354       2          0  46.451975 -117.545403
#
# [6355 rows x 8 columns]

# %%
dates3 = ['03-23', '03-24', '03-25', '03-26', '03-27', '03-28', '03-29', '03-30', '03-31', '04-01', '04-02',
         '04-03', '04-04', '04-05', '04-06', '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13',
         '04-14', '04-15','04-16', '04-17', '04-18', '04-19', '04-20', '04-21']

for x in range(len(dates3)):
    url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/' + dates3[x] + '-2020.csv'
    response = requests.get(url)

    df1 = pd.read_csv(url)
    df1 = df1.rename(columns={"Province_State": "Province/State", "Country_Region": "Country/Region", "Last_Update": "Last Update", "Lat":"Latitude", "Long_":"Longitude"})
    df1 = df1[["Province/State", "Country/Region", "Last Update", "Confirmed", "Deaths", "Recovered", "Latitude", "Longitude"]]

    df1['Last Update'] = df1['Last Update'].apply(lambda x : "0" + x[6:10] + "/2020")
    df1['Last Update'] = df1['Last Update'].apply(lambda x : x.replace("-", "/"))
    mask = df1['Last Update'] == df1['Last Update'][0]
    df1 = df1.loc[mask]
    states = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
          "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
          "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", 
          "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", 
          "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", 
          "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
          "West Virginia", "Wisconsin", "Wyoming", "District of Columbia"]
    abb = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", 
       "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH",
       "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "DC"]

    for x in range(51):
        df1["Province/State"] = df1["Province/State"].replace(states[x], abb[x])

    df = df.append(df1, ignore_index = True)
    
df
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#        Confirmed        Country/Region   Deaths Last Update   Latitude  \
# 0            1.0        Mainland China      NaN  01/22/2020        NaN
# 1           14.0        Mainland China      NaN  01/22/2020        NaN
# 2            6.0        Mainland China      NaN  01/22/2020        NaN
# 3            1.0        Mainland China      NaN  01/22/2020        NaN
# 4            NaN        Mainland China      NaN  01/22/2020        NaN
# 5           26.0        Mainland China      NaN  01/22/2020        NaN
# 6            2.0        Mainland China      NaN  01/22/2020        NaN
# 7            1.0        Mainland China      NaN  01/22/2020        NaN
# 8            4.0        Mainland China      NaN  01/22/2020        NaN
# 9            1.0        Mainland China      NaN  01/22/2020        NaN
# 10           NaN        Mainland China      NaN  01/22/2020        NaN
# 11           5.0        Mainland China      NaN  01/22/2020        NaN
# 12           NaN             Hong Kong      NaN  01/22/2020        NaN
# 13         444.0        Mainland China     17.0  01/22/2020        NaN
# 14           4.0        Mainland China      NaN  01/22/2020        NaN
# 15           NaN        Mainland China      NaN  01/22/2020        NaN
# 16           1.0        Mainland China      NaN  01/22/2020        NaN
# 17           2.0        Mainland China      NaN  01/22/2020        NaN
# 18           NaN        Mainland China      NaN  01/22/2020        NaN
# 19           2.0        Mainland China      NaN  01/22/2020        NaN
# 20           1.0                 Macau      NaN  01/22/2020        NaN
# 21           1.0        Mainland China      NaN  01/22/2020        NaN
# 22           NaN        Mainland China      NaN  01/22/2020        NaN
# 23           NaN        Mainland China      NaN  01/22/2020        NaN
# 24           2.0        Mainland China      NaN  01/22/2020        NaN
# 25           9.0        Mainland China      NaN  01/22/2020        NaN
# 26           1.0        Mainland China      NaN  01/22/2020        NaN
# 27           5.0        Mainland China      NaN  01/22/2020        NaN
# 28           1.0                Taiwan      NaN  01/22/2020        NaN
# 29           4.0        Mainland China      NaN  01/22/2020        NaN
# ...          ...                   ...      ...         ...        ...
# 98180     3465.0          South Africa     58.0  04/21/2020 -30.559500
# 98181        4.0           South Sudan      0.0  04/21/2020   6.877000
# 98182   204178.0                 Spain  21282.0  04/21/2020  40.463667
# 98183      310.0             Sri Lanka      7.0  04/21/2020   7.873054
# 98184      107.0                 Sudan     12.0  04/21/2020  12.862800
# 98185       10.0              Suriname      1.0  04/21/2020   3.919300
# 98186    15322.0                Sweden   1765.0  04/21/2020  60.128161
# 98187    28063.0           Switzerland   1478.0  04/21/2020  46.818200
# 98188       42.0                 Syria      3.0  04/21/2020  34.802075
# 98189      425.0               Taiwan*      6.0  04/21/2020  23.700000
# 98190      254.0              Tanzania     10.0  04/21/2020  -6.369028
# 98191     2811.0              Thailand     48.0  04/21/2020  15.870032
# 98192       23.0           Timor-Leste      0.0  04/21/2020  -8.874217
# 98193       86.0                  Togo      6.0  04/21/2020   8.619500
# 98194      115.0   Trinidad and Tobago      8.0  04/21/2020  10.691800
# 98195      884.0               Tunisia     38.0  04/21/2020  33.886917
# 98196    95591.0                Turkey   2259.0  04/21/2020  38.963700
# 98197       61.0                Uganda      0.0  04/21/2020   1.373333
# 98198     6125.0               Ukraine    161.0  04/21/2020  48.379400
# 98199     7755.0  United Arab Emirates     46.0  04/21/2020  23.424076
# 98200   129044.0        United Kingdom  17337.0  04/21/2020  55.378100
# 98201      535.0               Uruguay     11.0  04/21/2020 -32.522800
# 98202     1678.0            Uzbekistan      6.0  04/21/2020  41.377491
# 98203      285.0             Venezuela     10.0  04/21/2020   6.423800
# 98204      268.0               Vietnam      0.0  04/21/2020  14.058324
# 98205      466.0    West Bank and Gaza      4.0  04/21/2020  31.952200
# 98206        6.0        Western Sahara      0.0  04/21/2020  24.215500
# 98207        1.0                 Yemen      0.0  04/21/2020  15.552727
# 98208       70.0                Zambia      3.0  04/21/2020 -13.133897
# 98209       28.0              Zimbabwe      3.0  04/21/2020 -19.015438
#
#         Longitude  Province/State  Recovered
# 0             NaN           Anhui        NaN
# 1             NaN         Beijing        NaN
# 2             NaN       Chongqing        NaN
# 3             NaN          Fujian        NaN
# 4             NaN           Gansu        NaN
# 5             NaN       Guangdong        NaN
# 6             NaN         Guangxi        NaN
# 7             NaN         Guizhou        NaN
# 8             NaN          Hainan        NaN
# 9             NaN           Hebei        NaN
# 10            NaN    Heilongjiang        NaN
# 11            NaN           Henan        NaN
# 12            NaN       Hong Kong        NaN
# 13            NaN           Hubei       28.0
# 14            NaN           Hunan        NaN
# 15            NaN  Inner Mongolia        NaN
# 16            NaN         Jiangsu        NaN
# 17            NaN         Jiangxi        NaN
# 18            NaN           Jilin        NaN
# 19            NaN        Liaoning        NaN
# 20            NaN           Macau        NaN
# 21            NaN         Ningxia        NaN
# 22            NaN         Qinghai        NaN
# 23            NaN         Shaanxi        NaN
# 24            NaN        Shandong        NaN
# 25            NaN        Shanghai        NaN
# 26            NaN          Shanxi        NaN
# 27            NaN         Sichuan        NaN
# 28            NaN          Taiwan        NaN
# 29            NaN         Tianjin        NaN
# ...           ...             ...        ...
# 98180   22.937500             NaN     1055.0
# 98181   31.307000             NaN        0.0
# 98182   -3.749220             NaN    82514.0
# 98183   80.771797             NaN      102.0
# 98184   30.217600             NaN        8.0
# 98185  -56.027800             NaN        6.0
# 98186   18.643501             NaN      550.0
# 98187    8.227500             NaN    19400.0
# 98188   38.996815             NaN        6.0
# 98189  121.000000             NaN      217.0
# 98190   34.888822             NaN       11.0
# 98191  100.992541             NaN     2108.0
# 98192  125.727539             NaN        1.0
# 98193    0.824800             NaN       56.0
# 98194  -61.222500             NaN       28.0
# 98195    9.537499             NaN      148.0
# 98196   35.243300             NaN    14918.0
# 98197   32.290275             NaN       38.0
# 98198   31.165600             NaN      367.0
# 98199   53.847818             NaN     1443.0
# 98200   -3.436000             NaN        0.0
# 98201  -55.765800             NaN      313.0
# 98202   64.585262             NaN      357.0
# 98203  -66.589700             NaN      117.0
# 98204  108.277199             NaN      216.0
# 98205   35.233200             NaN       71.0
# 98206  -12.885800             NaN        0.0
# 98207   48.516388             NaN        0.0
# 98208   27.849332             NaN       35.0
# 98209   29.154857             NaN        2.0
#
# [98210 rows x 8 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/LatLongdata.csv', index = False)

# %%
latlon = pd.read_csv('/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/LatLongdata.csv')
latlon
# Out:
#       Province/State        Country/Region Last Update  Confirmed  Deaths  \
# 0                 ei        Mainland China  03/01/2020      66907    2761
# 1                 ne           South Korea  03/01/2020       3736      17
# 2                 ne                 Italy  03/01/2020       1694      34
# 3                 ng        Mainland China  03/01/2020       1349       7
# 4                 an        Mainland China  03/01/2020       1272      22
# 5                 ng        Mainland China  03/01/2020       1205       1
# 6                 an        Mainland China  03/01/2020       1018       4
# 7                 ui        Mainland China  03/01/2020        990       6
# 8                 ne                  Iran  03/01/2020        978      54
# 9                 xi        Mainland China  03/01/2020        935       1
# 10                ng        Mainland China  03/01/2020        758       6
# 11                su        Mainland China  03/01/2020        631       0
# 12                ng        Mainland China  03/01/2020        576       6
# 13                an        Mainland China  03/01/2020        538       3
# 14                ng        Mainland China  03/01/2020        480      13
# 15                ng        Mainland China  03/01/2020        413       8
# 16                ai        Mainland China  03/01/2020        337       3
# 17                ei        Mainland China  03/01/2020        318       6
# 18                an        Mainland China  03/01/2020        296       1
# 19                ne                 Japan  03/01/2020        256       6
# 20                xi        Mainland China  03/01/2020        252       2
# 21                xi        Mainland China  03/01/2020        245       1
# 22                an        Mainland China  03/01/2020        174       2
# 23                an        Mainland China  03/01/2020        168       5
# 24                in        Mainland China  03/01/2020        136       3
# 25                xi        Mainland China  03/01/2020        133       0
# 26                ne                France  03/01/2020        130       2
# 27                ne               Germany  03/01/2020        130       0
# 28                ng        Mainland China  03/01/2020        122       1
# 29                ne             Singapore  03/01/2020        106       0
# ...              ...                   ...         ...        ...     ...
# 38467            NaN              Slovakia  04/01/2020        400       1
# 38468            NaN              Slovenia  04/01/2020        841      15
# 38469            NaN               Somalia  04/01/2020          5       0
# 38470            NaN          South Africa  04/01/2020       1380       5
# 38471            NaN                 Spain  04/01/2020     104118    9387
# 38472            NaN             Sri Lanka  04/01/2020        146       3
# 38473            NaN                 Sudan  04/01/2020          7       2
# 38474            NaN              Suriname  04/01/2020         10       0
# 38475            NaN                Sweden  04/01/2020       4947     239
# 38476            NaN           Switzerland  04/01/2020      17768     488
# 38477            NaN                 Syria  04/01/2020         10       2
# 38478            NaN               Taiwan*  04/01/2020        329       5
# 38479            NaN              Tanzania  04/01/2020         20       1
# 38480            NaN              Thailand  04/01/2020       1771      12
# 38481            NaN           Timor-Leste  04/01/2020          1       0
# 38482            NaN                  Togo  04/01/2020         36       2
# 38483            NaN   Trinidad and Tobago  04/01/2020         90       5
# 38484            NaN               Tunisia  04/01/2020        423      12
# 38485            NaN                Turkey  04/01/2020      15679     277
# 38486            NaN                Uganda  04/01/2020         44       0
# 38487            NaN               Ukraine  04/01/2020        794      20
# 38488            NaN  United Arab Emirates  04/01/2020        814       8
# 38489            NaN        United Kingdom  04/01/2020      29474    2352
# 38490            NaN               Uruguay  04/01/2020        338       2
# 38491            NaN            Uzbekistan  04/01/2020        181       2
# 38492            NaN             Venezuela  04/01/2020        143       3
# 38493            NaN               Vietnam  04/01/2020        218       0
# 38494            NaN    West Bank and Gaza  04/01/2020        134       1
# 38495            NaN                Zambia  04/01/2020         36       0
# 38496            NaN              Zimbabwe  04/01/2020          8       1
#
#        Recovered   Latitude   Longitude
# 0          31536  30.975600  112.270700
# 1             30  36.000000  128.000000
# 2             83  43.000000   12.000000
# 3           1016  23.341700  113.424400
# 4           1198  33.882000  113.614000
# 5           1046  29.183200  120.093400
# 6            866  27.610400  111.708800
# 7            873  31.825700  117.226400
# 8            175  32.000000   53.000000
# 9            831  27.614000  115.722100
# 10           443  36.342700  118.149800
# 11           536  32.971100  119.455000
# 12           450  30.057200  107.874000
# 13           365  30.617100  102.710300
# 14           342  47.862000  127.761500
# 15           276  40.182400  116.414200
# 16           290  31.202000  121.449100
# 17           294  38.042800  114.514900
# 18           247  26.078900  117.987400
# 19            32  36.000000  138.000000
# 20           181  23.829800  108.788100
# 21           208  35.191700  108.870100
# 22           163  24.974000  101.487000
# 23           149  19.195900  109.745300
# 24           111  39.305400  117.323000
# 25           116  37.577700  112.292200
# 26            12  47.000000    2.000000
# 27            16  51.000000    9.000000
# 28           103  41.295600  122.608500
# 29            72   1.283300  103.833300
# ...          ...        ...         ...
# 38467          3  48.669000   19.699000
# 38468         10  46.151200   14.995500
# 38469          1   5.152149   46.199616
# 38470         50 -30.559500   22.937500
# 38471      22647  40.463667   -3.749220
# 38472         21   7.873054   80.771797
# 38473          2  12.862800   30.217600
# 38474          0   3.919300  -56.027800
# 38475        103  60.128161   18.643501
# 38476       2967  46.818200    8.227500
# 38477          0  34.802075   38.996815
# 38478         39  23.700000  121.000000
# 38479          1  -6.369028   34.888822
# 38480        505  15.870032  100.992541
# 38481          0  -8.874217  125.727539
# 38482         10   8.619500    0.824800
# 38483          1  10.691800  -61.222500
# 38484          5  33.886917    9.537499
# 38485        333  38.963700   35.243300
# 38486          0   1.373333   32.290275
# 38487         13  48.379400   31.165600
# 38488         61  23.424076   53.847818
# 38489        135  55.378100   -3.436000
# 38490         41 -32.522800  -55.765800
# 38491         12  41.377491   64.585262
# 38492         41   6.423800  -66.589700
# 38493         63  14.058324  108.277199
# 38494         18  31.952200   35.233200
# 38495          0 -13.133897   27.849332
# 38496          0 -19.015438   29.154857
#
# [38497 rows x 8 columns]

# %%
mask = latlon["Country/Region"] == "US"
df = latlon.loc[mask]
df
# Out:
#                  Province/State Country/Region Last Update  Confirmed  Deaths  \
# 50                           WA             US  03/01/2020          9       1
# 63                           IL             US  03/01/2020          3       0
# 67                           WA             US  03/01/2020          2       0
# 73                           RI             US  03/01/2020          1       0
# 113                          s)             US  03/02/2020         45       0
# 124                          WA             US  03/02/2020         14       5
# 127                          CA             US  03/02/2020          9       0
# 132                          IL             US  03/02/2020          4       0
# 133                          WA             US  03/02/2020          4       1
# 139                          OR             US  03/02/2020          2       0
# 140                          RI             US  03/02/2020          2       0
# 148                          NH             US  03/02/2020          1       0
# 149                          FL             US  03/02/2020          1       0
# 150                          NY             US  03/02/2020          1       0
# 151                          CA             US  03/02/2020          1       0
# 152                          CA             US  03/02/2020          1       0
# 153                          FL             US  03/02/2020          1       0
# 154                          CA             US  03/02/2020          1       0
# 155                          OR             US  03/02/2020          1       0
# 201                          WA             US  03/03/2020         21       6
# 209                          CA             US  03/03/2020         11       0
# 217                          WA             US  03/03/2020          6       1
# 227                          GA             US  03/03/2020          2       0
# 228                          NH             US  03/03/2020          2       0
# 229                          FL             US  03/03/2020          2       0
# 230                          CA             US  03/03/2020          2       0
# 231                          OR             US  03/03/2020          2       0
# 237                          MA             US  03/03/2020          1       0
# 238                          CA             US  03/03/2020          1       0
# 239                          WI             US  03/03/2020          1       0
# ...                         ...            ...         ...        ...     ...
# 38232                        OH             US  04/01/2020          2       0
# 38233                        KS             US  04/01/2020         93       4
# 38234                        NY             US  04/01/2020         10       1
# 38235                        VA             US  04/01/2020          2       0
# 38236                        NC             US  04/01/2020          3       0
# 38237                        WA             US  04/01/2020        161       3
# 38238                        MS             US  04/01/2020          6       0
# 38239                        OR             US  04/01/2020         17       3
# 38240                        SD             US  04/01/2020          8       0
# 38241                        AZ             US  04/01/2020         24       0
# 38242                        MS             US  04/01/2020          9       0
# 38243                        MN             US  04/01/2020          1       0
# 38244                        MT             US  04/01/2020         32       0
# 38245                        CA             US  04/01/2020         25       1
# 38246                        ME             US  04/01/2020         59       1
# 38247                        NE             US  04/01/2020          1       0
# 38248                        PA             US  04/01/2020         79       0
# 38249                        SC             US  04/01/2020         66       1
# 38250                        VA             US  04/01/2020         16       1
# 38251                        TX             US  04/01/2020          3       0
# 38252                        CA             US  04/01/2020          7       0
# 38253                        AZ             US  04/01/2020         12       0
# 38254                        CO             US  04/01/2020          2       0
# 38267          Diamond Princess             US  04/01/2020         49       0
# 38275            Grand Princess             US  04/01/2020        103       3
# 38278                      Guam             US  04/01/2020         77       3
# 38294  Northern Mariana Islands             US  04/01/2020          6       1
# 38300               Puerto Rico             US  04/01/2020        286      11
# 38304                 Recovered             US  04/01/2020          0       0
# 38318            Virgin Islands             US  04/01/2020         30       0
#
#        Recovered   Latitude   Longitude
# 50             1  47.606200 -122.332100
# 63             2  41.878100  -87.629800
# 67             0  48.033000 -121.833900
# 73             0  41.824000  -71.412800
# 113            0  35.443700  139.638000
# 124            1  47.548000 -121.983600
# 127            1  37.354100 -121.955200
# 132            2  41.737700  -87.697600
# 133            0  48.033000 -121.833900
# 139            0  45.505100 -122.675000
# 140            0  41.824000  -71.412800
# 148            0  43.908800  -71.826000
# 149            0  27.990400  -82.301800
# 150            0  40.712800  -74.006000
# 151            0  39.091600 -120.803900
# 152            0  37.563000 -122.325500
# 153            0  27.336400  -82.530700
# 154            0  38.578000 -122.988800
# 155            0  45.775000 -118.760600
# 201            1  47.548000 -121.983600
# 209            1  37.354100 -121.955200
# 217            0  48.033000 -121.833900
# 227            0  33.803400  -84.396300
# 228            0  43.908800  -71.826000
# 229            0  27.990400  -82.301800
# 230            0  37.563000 -122.325500
# 231            0  45.547000 -123.138600
# 237            0  42.176700  -71.144900
# 238            0  37.871500 -122.273000
# 239            1  43.073100  -89.401200
# ...          ...        ...         ...
# 38232          0  40.843396  -83.307342
# 38233          0  39.117273  -94.763782
# 38234          0  42.701451  -78.221996
# 38235          0  36.915820  -81.078341
# 38236          0  36.162226  -80.662394
# 38237          0  46.457385 -120.738013
# 38238          0  34.028242  -89.707620
# 38239          0  45.233304 -123.308696
# 38240          0  43.009245  -97.394676
# 38241          0  34.599339 -112.553859
# 38242          0  32.778904  -90.396561
# 38243          0  44.717102  -95.868425
# 38244          0  45.939559 -108.269149
# 38245          0  38.682789 -121.901829
# 38246          0  43.478084  -70.710524
# 38247          0  40.872726  -97.597102
# 38248          0  39.921009  -76.730401
# 38249          0  34.972815  -81.180859
# 38250          0  37.243748  -76.544128
# 38251          0  33.176597  -98.687909
# 38252          0  39.262559 -121.353564
# 38253          0  32.768957 -113.906667
# 38254          0  40.003468 -102.425867
# 38267          0   0.000000    0.000000
# 38275          0   0.000000    0.000000
# 38278          0  13.444300  144.793700
# 38294          0  15.097900  145.673900
# 38300          0  18.220800  -66.590100
# 38304       8474   0.000000    0.000000
# 38318          0  18.335800  -64.896300
#
# [33740 rows x 8 columns]

# %%
df.to_csv('/Users/markomiholjcic/Documents/GitHub/COMP5360Project/project_files/csv_files/USLatLon.csv', index = False)
